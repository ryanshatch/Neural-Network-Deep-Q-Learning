# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
# %pip install numpy
# %pip install gym
# %pip install torch
# %pip install matplotlib
# %pip install tensorflow
# %pip install keras

# %%
#* Version 1: Main code for default parameters.

import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.8822202429488013, score: 45
# Scores: (min: 45, avg: 45, max: 45)
#
# Run: 2, exploration: 0.7514768435208588, score: 33
# Scores: (min: 33, avg: 39, max: 45)
#
# Run: 3, exploration: 0.6832098777212641, score: 20
# Scores: (min: 20, avg: 32.666666666666664, max: 45)
#
# Run: 4, exploration: 0.6305556603555866, score: 17
# Scores: (min: 17, avg: 28.75, max: 45)
#
# Run: 5, exploration: 0.6088145090359074, score: 8
# Scores: (min: 8, avg: 24.6, max: 45)
#
# Run: 6, exploration: 0.5790496471185967, score: 11
# Scores: (min: 8, avg: 22.333333333333332, max: 45)
#
# Run: 7, exploration: 0.5290920728090721, score: 19
# Scores: (min: 8, avg: 21.857142857142858, max: 45)
#
# Run: 8, exploration: 0.4932355662165453, score: 15
# Scores: (min: 8, avg: 21, max: 45)
#
# Run: 9, exploration: 0.46444185833082485, score: 13
# Scores: (min: 8, avg: 20.11111111111111, max: 45)
#
# Run: 10, exploration: 0.43952667968844233, score: 12
# Scores: (min: 8, avg: 19.3, max: 45)
#
# Run: 11, exploration: 0.4117990041127769, score: 14
# Scores: (min: 8, avg: 18.818181818181817, max: 45)
#
# Run: 12, exploration: 0.39166620452737816, score: 11
# Scores: (min: 8, avg: 18.166666666666668, max: 45)
#
# Run: 13, exploration: 0.3669578217261671, score: 14
# Scores: (min: 8, avg: 17.846153846153847, max: 45)
#
# Run: 14, exploration: 0.3543053533848483, score: 8
# Scores: (min: 8, avg: 17.142857142857142, max: 45)
#
# Run: 15, exploration: 0.3386767948568688, score: 10
# Scores: (min: 8, avg: 16.666666666666668, max: 45)
#
# Run: 16, exploration: 0.322118930542046, score: 11
# Scores: (min: 8, avg: 16.3125, max: 45)
#
# Run: 17, exploration: 0.3079101286968243, score: 10
# Scores: (min: 8, avg: 15.941176470588236, max: 45)
#
# Run: 18, exploration: 0.29285644267656924, score: 11
# Scores: (min: 8, avg: 15.666666666666666, max: 45)
#
# Run: 19, exploration: 0.27714603575484437, score: 12
# Scores: (min: 8, avg: 15.473684210526315, max: 45)
#
# Run: 20, exploration: 0.2649210072611673, score: 10
# Scores: (min: 8, avg: 15.2, max: 45)
#
# Run: 21, exploration: 0.25450776877280124, score: 9
# Scores: (min: 8, avg: 14.904761904761905, max: 45)
#
# Run: 22, exploration: 0.2457325055235537, score: 8
# Scores: (min: 8, avg: 14.590909090909092, max: 45)
#
# Run: 23, exploration: 0.23371867538818816, score: 11
# Scores: (min: 8, avg: 14.434782608695652, max: 45)
#
# Run: 24, exploration: 0.2211807388415433, score: 12
# Scores: (min: 8, avg: 14.333333333333334, max: 45)
#
# Run: 25, exploration: 0.21142436319205632, score: 10
# Scores: (min: 8, avg: 14.16, max: 45)
#
# Run: 26, exploration: 0.2041345879004775, score: 8
# Scores: (min: 8, avg: 13.923076923076923, max: 45)
#
# Run: 27, exploration: 0.19709615934585656, score: 8
# Scores: (min: 8, avg: 13.703703703703704, max: 45)
#
# Run: 28, exploration: 0.18840216465300522, score: 10
# Scores: (min: 8, avg: 13.571428571428571, max: 45)
#
# Run: 29, exploration: 0.17829525136613786, score: 12
# Scores: (min: 8, avg: 13.517241379310345, max: 45)
#
# Run: 30, exploration: 0.17043057265153258, score: 10
# Scores: (min: 8, avg: 13.4, max: 45)
#
# Run: 31, exploration: 0.16209824418995536, score: 11
# Scores: (min: 8, avg: 13.32258064516129, max: 45)
#
# Run: 32, exploration: 0.1534024157688821, score: 12
# Scores: (min: 8, avg: 13.28125, max: 45)
#
# Run: 33, exploration: 0.14663577052834775, score: 10
# Scores: (min: 8, avg: 13.181818181818182, max: 45)
#
# Run: 34, exploration: 0.14016760486247823, score: 10
# Scores: (min: 8, avg: 13.088235294117647, max: 45)
#
# Run: 35, exploration: 0.13398475271138335, score: 10
# Scores: (min: 8, avg: 13, max: 45)
#
# Run: 36, exploration: 0.12807462877562611, score: 10
# Scores: (min: 8, avg: 12.916666666666666, max: 45)
#
# Run: 37, exploration: 0.12242520289863423, score: 10
# Scores: (min: 8, avg: 12.837837837837839, max: 45)
#
# Run: 38, exploration: 0.11643985070121858, score: 11
# Scores: (min: 8, avg: 12.789473684210526, max: 45)
#
# Run: 39, exploration: 0.11074712159185099, score: 11
# Scores: (min: 8, avg: 12.743589743589743, max: 45)
#
# Run: 40, exploration: 0.10533270926593409, score: 11
# Scores: (min: 8, avg: 12.7, max: 45)
#
# Run: 41, exploration: 0.10119240105273684, score: 9
# Scores: (min: 8, avg: 12.609756097560975, max: 45)
#
# Run: 42, exploration: 0.09624511776741324, score: 11
# Scores: (min: 8, avg: 12.571428571428571, max: 45)
#
# Run: 43, exploration: 0.0906265979439563, score: 13
# Scores: (min: 8, avg: 12.581395348837209, max: 45)
#
# Run: 44, exploration: 0.08662902049662846, score: 10
# Scores: (min: 8, avg: 12.522727272727273, max: 45)
#
# Run: 45, exploration: 0.08280777787605056, score: 10
# Scores: (min: 8, avg: 12.466666666666667, max: 45)
#
# Run: 46, exploration: 0.07915509187866444, score: 10
# Scores: (min: 8, avg: 12.41304347826087, max: 45)
#
# Run: 47, exploration: 0.07566352740075044, score: 10
# Scores: (min: 8, avg: 12.361702127659575, max: 45)
#
# Run: 48, exploration: 0.07196434741762824, score: 11
# Scores: (min: 8, avg: 12.333333333333334, max: 45)
#
# Run: 49, exploration: 0.06844601986126451, score: 11
# Scores: (min: 8, avg: 12.306122448979592, max: 45)
#
# Run: 50, exploration: 0.06575561514114299, score: 9
# Scores: (min: 8, avg: 12.24, max: 45)
#
# Run: 51, exploration: 0.06317096204211972, score: 9
# Scores: (min: 8, avg: 12.176470588235293, max: 45)
#
# Run: 52, exploration: 0.06038446427088321, score: 10
# Scores: (min: 8, avg: 12.134615384615385, max: 45)
#
# Run: 53, exploration: 0.058010934765067, score: 9
# Scores: (min: 8, avg: 12.075471698113208, max: 45)
#
# Run: 54, exploration: 0.05573070148010834, score: 9
# Scores: (min: 8, avg: 12.018518518518519, max: 45)
#
# Run: 55, exploration: 0.05354009722551939, score: 9
# Scores: (min: 8, avg: 11.963636363636363, max: 45)
#
# Run: 56, exploration: 0.051178420962124486, score: 10
# Scores: (min: 8, avg: 11.928571428571429, max: 45)
#
# Run: 57, exploration: 0.04916675299948831, score: 9
# Scores: (min: 8, avg: 11.87719298245614, max: 45)
#
# Run: 58, exploration: 0.047234157581800176, score: 9
# Scores: (min: 8, avg: 11.827586206896552, max: 45)
#
# Run: 59, exploration: 0.045605554379880814, score: 8
# Scores: (min: 8, avg: 11.76271186440678, max: 45)
#
# Run: 60, exploration: 0.043812938841152796, score: 9
# Scores: (min: 8, avg: 11.716666666666667, max: 45)
#
# Run: 61, exploration: 0.0418803316354751, score: 10
# Scores: (min: 8, avg: 11.688524590163935, max: 45)
#
# Run: 62, exploration: 0.040032972548509065, score: 10
# Scores: (min: 8, avg: 11.661290322580646, max: 45)
#
# Run: 63, exploration: 0.03845939824099909, score: 9
# Scores: (min: 8, avg: 11.619047619047619, max: 45)
#
# Run: 64, exploration: 0.03694767635022522, score: 9
# Scores: (min: 8, avg: 11.578125, max: 45)
#
# Run: 65, exploration: 0.035673744367776934, score: 8
# Scores: (min: 8, avg: 11.523076923076923, max: 45)
#
# Run: 66, exploration: 0.034100160462149656, score: 10
# Scores: (min: 8, avg: 11.5, max: 45)
#
# Run: 67, exploration: 0.03275978694079333, score: 9
# Scores: (min: 8, avg: 11.462686567164178, max: 45)
#
# Run: 68, exploration: 0.031158165231288826, score: 11
# Scores: (min: 8, avg: 11.455882352941176, max: 45)
#
# Run: 69, exploration: 0.029783765425331846, score: 10
# Scores: (min: 8, avg: 11.434782608695652, max: 45)
#
# Run: 70, exploration: 0.028756840457888354, score: 8
# Scores: (min: 8, avg: 11.385714285714286, max: 45)
#
# Run: 71, exploration: 0.027626496583102015, score: 9
# Scores: (min: 8, avg: 11.352112676056338, max: 45)
#
# Run: 72, exploration: 0.026407880170317945, score: 10
# Scores: (min: 8, avg: 11.333333333333334, max: 45)
#
# Run: 73, exploration: 0.02524301744132218, score: 10
# Scores: (min: 8, avg: 11.315068493150685, max: 45)
#
# Run: 74, exploration: 0.024129537298457977, score: 10
# Scores: (min: 8, avg: 11.297297297297296, max: 45)
#
# Run: 75, exploration: 0.022949847368015076, score: 11
# Scores: (min: 8, avg: 11.293333333333333, max: 45)
#
# Run: 76, exploration: 0.021937519923982282, score: 10
# Scores: (min: 8, avg: 11.276315789473685, max: 45)
#
# Run: 77, exploration: 0.021075222784267326, score: 9
# Scores: (min: 8, avg: 11.246753246753247, max: 45)
#
# Run: 78, exploration: 0.020145585821044927, score: 10
# Scores: (min: 8, avg: 11.23076923076923, max: 45)
#
# Run: 79, exploration: 0.019256955536244666, score: 10
# Scores: (min: 8, avg: 11.215189873417721, max: 45)
#
# Run: 80, exploration: 0.018407523107991184, score: 10
# Scores: (min: 8, avg: 11.2, max: 45)
#
# Run: 81, exploration: 0.017595559502304726, score: 10
# Scores: (min: 8, avg: 11.185185185185185, max: 45)
# Run: 82, exploration: 0.016903931611681827, score: 9
# Scores: (min: 8, avg: 11.158536585365853, max: 45)
#
# Run: 83, exploration: 0.01615829206087557, score: 10
# Scores: (min: 8, avg: 11.144578313253012, max: 45)
#
# Run: 84, exploration: 0.015445542985048652, score: 10
# Scores: (min: 8, avg: 11.130952380952381, max: 45)
#
# Run: 85, exploration: 0.014838425699981627, score: 9
# Scores: (min: 8, avg: 11.105882352941176, max: 45)
#
# Run: 86, exploration: 0.014326806379480736, score: 8
# Scores: (min: 8, avg: 11.069767441860465, max: 45)
#
# Run: 87, exploration: 0.013763663225419333, score: 9
# Scores: (min: 8, avg: 11.045977011494253, max: 45)
#
# Run: 88, exploration: 0.013222655514775413, score: 9
# Scores: (min: 8, avg: 11.022727272727273, max: 45)
#
# Run: 89, exploration: 0.012639398604785928, score: 10
# Scores: (min: 8, avg: 11.01123595505618, max: 45)
#
# Run: 90, exploration: 0.01208186940302195, score: 10
# Scores: (min: 8, avg: 11, max: 45)
#
# Run: 91, exploration: 0.01154893304942575, score: 10
# Scores: (min: 8, avg: 10.989010989010989, max: 45)
#
# Run: 92, exploration: 0.01098430721937979, score: 11
# Scores: (min: 8, avg: 10.98913043478261, max: 45)
#
# Run: 93, exploration: 0.010552547534153616, score: 9
# Scores: (min: 8, avg: 10.96774193548387, max: 45)
#
# Run: 94, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.98936170212766, max: 45)
#
# Run: 95, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.031578947368422, max: 45)
#
# Run: 96, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.03125, max: 45)
#
# Run: 97, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.041237113402062, max: 45)
#
# Run: 98, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.040816326530612, max: 45)
#
# Run: 99, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.080808080808081, max: 45)
#
# Run: 100, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.16, max: 45)
#
# Run: 101, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 10.87, max: 33)
#
# Run: 102, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.68, max: 20)
#
# Run: 103, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 10.65, max: 19)
#
# Run: 104, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 10.75, max: 27)
#
# Run: 105, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 11.06, max: 39)
#
# Run: 106, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 11.82, max: 87)
#
# Run: 107, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 11.92, max: 87)
#
# Run: 108, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 12.32, max: 87)
#
# Run: 109, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 12.62, max: 87)
#
# Run: 110, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.71, max: 87)
#
# Run: 111, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 12.88, max: 87)
#
# Run: 112, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.89, max: 87)
#
# Run: 113, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 13.95, max: 120)
#
# Run: 114, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 14.23, max: 120)
#
# Run: 115, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 14.57, max: 120)
#
# Run: 116, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.66, max: 120)
#
# Run: 117, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.72, max: 120)
#
# Run: 118, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.73, max: 120)
#
# Run: 119, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.74, max: 120)
#
# Run: 120, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.79, max: 120)
#
# Run: 121, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.85, max: 120)
#
# Run: 122, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.89, max: 120)
#
# Run: 123, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.94, max: 120)
#
# Run: 124, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.97, max: 120)
#
# Run: 125, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.03, max: 120)
#
# Run: 126, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.06, max: 120)
#
# Run: 127, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.11, max: 120)
#
# Run: 128, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.12, max: 120)
#
# Run: 129, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.12, max: 120)
#
# Run: 130, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.18, max: 120)
#
# Run: 131, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.22, max: 120)
#
# Run: 132, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.25, max: 120)
#
# Run: 133, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.32, max: 120)
#
# Run: 134, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.36, max: 120)
#
# Run: 135, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.41, max: 120)
#
# Run: 136, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.48, max: 120)
#
# Run: 137, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.52, max: 120)
#
# Run: 138, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.53, max: 120)
#
# Run: 139, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.52, max: 120)
#
# Run: 140, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.54, max: 120)
#
# Run: 141, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.64, max: 120)
#
# Run: 142, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.68, max: 120)
#
# Run: 143, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.73, max: 120)
#
# Run: 144, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.76, max: 120)
#
# Run: 145, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.78, max: 120)
#
# Run: 146, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.87, max: 120)
#
# Run: 147, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.94, max: 120)
#
# Run: 148, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.95, max: 120)
#
# Run: 149, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 16.14, max: 120)
#
# Run: 150, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 16.35, max: 120)
#
# Run: 151, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.42, max: 120)
#
# Run: 152, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.49, max: 120)
#
# Run: 153, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.53, max: 120)
#
# Run: 154, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.55, max: 120)
#
# Run: 155, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.6, max: 120)
#
# Run: 156, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 16.81, max: 120)
#
# Run: 157, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.86, max: 120)
#
# Run: 158, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 17, max: 120)
#
# Run: 159, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 17.23, max: 120)
#
# Run: 160, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 17.55, max: 120)
#
# Run: 161, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 17.85, max: 120)
#
# Run: 162, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 18.12, max: 120)
#
# Run: 163, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 18.68, max: 120)
#
# Run: 164, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 18.85, max: 120)
#
# Run: 165, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 19.32, max: 120)
#
# Run: 166, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.34, max: 120)
#
# Run: 167, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.4, max: 120)
#
# Run: 168, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 19.68, max: 120)
#
# Run: 169, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 20.11, max: 120)
#
# Run: 170, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 21, max: 120)
#
# Run: 171, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 22.13, max: 122)
#
# Run: 172, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 23.18, max: 122)
#
# Run: 173, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 23.73, max: 122)
#
# Run: 174, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 24.15, max: 122)
#
# Run: 175, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 24.56, max: 122)
#
# Run: 176, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 25.21, max: 122)
#
# Run: 177, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 26.16, max: 122)
#
# Run: 178, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 26.33, max: 122)
#
# Run: 179, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 27.8, max: 157)
#
# Run: 180, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 28.57, max: 157)
#
# Run: 181, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 29.03, max: 157)
# Run: 182, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 29.54, max: 157)
#
# Run: 183, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 30.8, max: 157)
#
# Run: 184, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 32.23, max: 157)
#
# Run: 185, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 32.49, max: 157)
#
# Run: 186, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 33.76, max: 157)
#
# Run: 187, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 34.9, max: 157)
#
# Run: 188, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 36.45, max: 164)
#
# Run: 189, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 37.52, max: 164)
#
# Run: 190, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 38.78, max: 164)
#
# Run: 191, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 40.11, max: 164)
#
# Run: 192, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 41.37, max: 164)
#
# Run: 193, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 42.75, max: 164)
#
# Run: 194, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 44.05, max: 164)
#
# Run: 195, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 45.27, max: 164)
#
# Run: 196, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 46.59, max: 164)
#
# Run: 197, exploration: 0.01, score: 158
# Scores: (min: 10, avg: 48.05, max: 164)
#
# Run: 198, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 49.41, max: 164)
#
# Run: 199, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 50.91, max: 165)
#
# Run: 200, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 52.14, max: 165)
#
# Run: 201, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 53.45, max: 165)
#
# Run: 202, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 54.84, max: 165)
#
# Run: 203, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 56.22, max: 165)
#
# Run: 204, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 57.66, max: 171)
#
# Run: 205, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 58.65, max: 171)
#
# Run: 206, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 59.55, max: 177)
#
# Run: 207, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 60.82, max: 177)
#
# Run: 208, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 62.01, max: 177)
#
# Run: 209, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 63.23, max: 177)
#
# Run: 210, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 64.58, max: 177)
#
# Run: 211, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 66.06, max: 179)
#
# Run: 212, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 67.64, max: 179)
#
# Run: 213, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 68.04, max: 179)
#
# Run: 214, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 69.23, max: 179)
#
# Run: 215, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 70.49, max: 179)
#
# Run: 216, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 71.88, max: 179)
#
# Run: 217, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 73.22, max: 179)
#
# Run: 218, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 74.8, max: 179)
#
# Run: 219, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 76.51, max: 184)
#
# Run: 220, exploration: 0.01, score: 186
# Scores: (min: 10, avg: 78.22, max: 186)
#
# Run: 221, exploration: 0.01, score: 235
# Scores: (min: 10, avg: 80.42, max: 235)
#
# Run: 222, exploration: 0.01, score: 188
# Scores: (min: 10, avg: 82.18, max: 235)
#
# Run: 223, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 83.69, max: 235)
#
# Run: 224, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 85.63, max: 235)
#
# Run: 225, exploration: 0.01, score: 212
# Scores: (min: 10, avg: 87.59, max: 235)
#
# Run: 226, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 89.05, max: 235)
#
# Run: 227, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 90.74, max: 235)
#
# Run: 228, exploration: 0.01, score: 218
# Scores: (min: 10, avg: 92.81, max: 235)
#
# Run: 229, exploration: 0.01, score: 230
# Scores: (min: 10, avg: 94.99, max: 235)
#
# Run: 230, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 96.74, max: 235)
#
# Run: 231, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 98.68, max: 235)
#
# Run: 232, exploration: 0.01, score: 278
# Scores: (min: 10, avg: 101.31, max: 278)
#
# Run: 233, exploration: 0.01, score: 233
# Scores: (min: 10, avg: 103.47, max: 278)
#
# Run: 234, exploration: 0.01, score: 343
# Scores: (min: 10, avg: 106.76, max: 343)
#
# Run: 235, exploration: 0.01, score: 303
# Scores: (min: 10, avg: 109.64, max: 343)
#
# Run: 236, exploration: 0.01, score: 208
# Scores: (min: 10, avg: 111.55, max: 343)
#
# Run: 237, exploration: 0.01, score: 245
# Scores: (min: 10, avg: 113.86, max: 343)
#
# Run: 238, exploration: 0.01, score: 232
# Scores: (min: 10, avg: 116.06, max: 343)
#
# Run: 239, exploration: 0.01, score: 308
# Scores: (min: 11, avg: 119.04, max: 343)
#
# Run: 240, exploration: 0.01, score: 224
# Scores: (min: 11, avg: 121.15, max: 343)
#
# Run: 241, exploration: 0.01, score: 237
# Scores: (min: 11, avg: 123.33, max: 343)
#
# Run: 242, exploration: 0.01, score: 186
# Scores: (min: 11, avg: 125.04, max: 343)
#
# Run: 243, exploration: 0.01, score: 234
# Scores: (min: 11, avg: 127.2, max: 343)
#
# Run: 244, exploration: 0.01, score: 242
# Scores: (min: 11, avg: 129.49, max: 343)
#
# Run: 245, exploration: 0.01, score: 249
# Scores: (min: 11, avg: 131.86, max: 343)
#
# Run: 246, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 136.67, max: 500)
#
# Run: 247, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 141.5, max: 500)
#
# Run: 248, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 146.38, max: 500)
#
# Run: 249, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 151.08, max: 500)
#
# Run: 250, exploration: 0.01, score: 206
# Scores: (min: 11, avg: 152.84, max: 500)
#
# Run: 251, exploration: 0.01, score: 499
# Scores: (min: 11, avg: 157.67, max: 500)
#
# Run: 252, exploration: 0.01, score: 197
# Scores: (min: 11, avg: 159.47, max: 500)
#
# Run: 253, exploration: 0.01, score: 298
# Scores: (min: 11, avg: 162.32, max: 500)
#
# Run: 254, exploration: 0.01, score: 365
# Scores: (min: 12, avg: 165.86, max: 500)
#
# Run: 255, exploration: 0.01, score: 307
# Scores: (min: 12, avg: 168.79, max: 500)
#
# Run: 256, exploration: 0.01, score: 499
# Scores: (min: 12, avg: 173.47, max: 500)
#
# Run: 257, exploration: 0.01, score: 245
# Scores: (min: 12, avg: 175.78, max: 500)
#
# Run: 258, exploration: 0.01, score: 176
# Scores: (min: 12, avg: 177.31, max: 500)
#
# Run: 259, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 182, max: 500)
#
# Run: 260, exploration: 0.01, score: 248
# Scores: (min: 12, avg: 184.07, max: 500)
#
# Run: 261, exploration: 0.01, score: 454
# Scores: (min: 12, avg: 188.21, max: 500)
#
# Run: 262, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 189.19, max: 500)
#
# Run: 263, exploration: 0.01, score: 265
# Scores: (min: 12, avg: 191.19, max: 500)
#
# Run: 264, exploration: 0.01, score: 21
# Scores: (min: 12, avg: 191.14, max: 500)
#
# Run: 265, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 190.7, max: 500)
#
# Run: 266, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 190.69, max: 500)
#
# Run: 267, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 190.64, max: 500)
#
# Run: 268, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 190.45, max: 500)
#
# Run: 269, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 190.14, max: 500)
#
# Run: 270, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 190.22, max: 500)
#
# Run: 271, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 190.53, max: 500)
#
# Run: 272, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 190.9, max: 500)
#
# Run: 273, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 191.68, max: 500)
#
# Run: 274, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 192.65, max: 500)
#
# Run: 275, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 194.12, max: 500)
#
# Run: 276, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 195.13, max: 500)
#
# Solved in 176 runs, 276 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-1cf8f762b4ce> in cartpole()
#      86             if terminal:
#      87                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 88                 score_logger.add_score(step, run)
#      89                 break
#      90             dqn_solver.experience_replay()
#
# U:\Module Five\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
  
from scores.score_logger import ScoreLogger

my_bool = bool(True)  # Define a NumPy boolean variable
  
ENV_NAME = "CartPole-v1"

#* Version 2 - Increased Exploration Decay to prolong the exploration phase

import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
#* Version 1: Main code for default parameters.

# GAMMA = 0.95  
# LEARNING_RATE = 0.001  
  
# MEMORY_SIZE = 1000000  
# BATCH_SIZE = 20  
  
# EXPLORATION_MAX = 1.0  
# EXPLORATION_MIN = 0.01  
# EXPLORATION_DECAY = 0.995

# * Version 2: Increased Exploration Decay

GAMMA = 0.95
LEARNING_RATE = 0.001
EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.99  # Slower decay, longer exploration phase
MEMORY_SIZE = 1000000
BATCH_SIZE = 20

# #* Version 3: Increased Learning Rate
# #
# # Experiment 3: Higher Learning Rate
# # GAMMA = 0.95
# # LEARNING_RATE = 0.005  # Faster learning
# # EXPLORATION_MAX = 1.0
# # EXPLORATION_MIN = 0.01
# # EXPLORATION_DECAY = 0.995
# # MEMORY_SIZE = 1000000
# # BATCH_SIZE = 20 
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 12
# Scores: (min: 12, avg: 12, max: 12)
#
# Run: 2, exploration: 0.9043820750088043, score: 18
# Scores: (min: 12, avg: 15, max: 18)
#
# Run: 3, exploration: 0.7936142836436553, score: 14
# Scores: (min: 12, avg: 14.666666666666666, max: 18)
#
# Run: 4, exploration: 0.682554595010387, score: 16
# Scores: (min: 12, avg: 15, max: 18)
#
# Run: 5, exploration: 0.536268225207185, score: 25
# Scores: (min: 12, avg: 17, max: 25)
#
# Run: 6, exploration: 0.4801414565714212, score: 12
# Scores: (min: 12, avg: 16.166666666666668, max: 25)
#
# Run: 7, exploration: 0.4298890135238936, score: 12
# Scores: (min: 12, avg: 15.571428571428571, max: 25)
#
# Run: 8, exploration: 0.40068465295154065, score: 8
# Scores: (min: 8, avg: 14.625, max: 25)
#
# Run: 9, exploration: 0.36603234127322926, score: 10
# Scores: (min: 8, avg: 14.11111111111111, max: 25)
#
# Run: 10, exploration: 0.34116606151404244, score: 8
# Scores: (min: 8, avg: 13.5, max: 25)
#
# Run: 11, exploration: 0.29938039131233124, score: 14
# Scores: (min: 8, avg: 13.545454545454545, max: 25)
#
# Run: 12, exploration: 0.2762516676992082, score: 9
# Scores: (min: 8, avg: 13.166666666666666, max: 25)
#
# Run: 13, exploration: 0.2549097606963092, score: 9
# Scores: (min: 8, avg: 12.846153846153847, max: 25)
#
# Run: 14, exploration: 0.23053581831852593, score: 11
# Scores: (min: 8, avg: 12.714285714285714, max: 25)
#
# Run: 15, exploration: 0.20849246173476127, score: 11
# Scores: (min: 8, avg: 12.6, max: 25)
#
# Run: 16, exploration: 0.1923853128939671, score: 9
# Scores: (min: 8, avg: 12.375, max: 25)
#
# Run: 17, exploration: 0.17574730149117582, score: 10
# Scores: (min: 8, avg: 12.235294117647058, max: 25)
#
# Run: 18, exploration: 0.16380796970808745, score: 8
# Scores: (min: 8, avg: 12, max: 25)
#
# Run: 19, exploration: 0.14519690621578268, score: 13
# Scores: (min: 8, avg: 12.052631578947368, max: 25)
#
# Run: 20, exploration: 0.13263987810938213, score: 10
# Scores: (min: 8, avg: 11.95, max: 25)
#
# Run: 21, exploration: 0.09144844271229946, score: 38
# Scores: (min: 8, avg: 13.19047619047619, max: 38)
#
# Run: 22, exploration: 0.07786448720191189, score: 17
# Scores: (min: 8, avg: 13.363636363636363, max: 38)
#
# Run: 23, exploration: 0.0643291962372672, score: 20
# Scores: (min: 8, avg: 13.652173913043478, max: 38)
#
# Run: 24, exploration: 0.05368359952302266, score: 19
# Scores: (min: 8, avg: 13.875, max: 38)
#
# Run: 25, exploration: 0.041338687854852486, score: 27
# Scores: (min: 8, avg: 14.4, max: 38)
#
# Run: 26, exploration: 0.026036082493920133, score: 47
# Scores: (min: 8, avg: 15.653846153846153, max: 47)
#
# Run: 27, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 19.925925925925927, max: 131)
#
# Run: 28, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 23.821428571428573, max: 131)
#
# Run: 29, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 24.96551724137931, max: 131)
#
# Run: 30, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 25.433333333333334, max: 131)
#
# Run: 31, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 26.903225806451612, max: 131)
#
# Run: 32, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 28.25, max: 131)
#
# Run: 33, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 28.575757575757574, max: 131)
#
# Run: 34, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 30.41176470588235, max: 131)
#
# Run: 35, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 33.82857142857143, max: 150)
#
# Run: 36, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 34.25, max: 150)
#
# Run: 37, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 35.648648648648646, max: 150)
#
# Run: 38, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 37.76315789473684, max: 150)
#
# Run: 39, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 38.97435897435897, max: 150)
#
# Run: 40, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 41.875, max: 155)
#
# Run: 41, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 42.707317073170735, max: 155)
#
# Run: 42, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 43.023809523809526, max: 155)
#
# Run: 43, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 43.30232558139535, max: 155)
#
# Run: 44, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 43.93181818181818, max: 155)
#
# Run: 45, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 44.2, max: 155)
#
# Run: 46, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 45.06521739130435, max: 155)
#
# Run: 47, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 45.212765957446805, max: 155)
#
# Run: 48, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 45.479166666666664, max: 155)
#
# Run: 49, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 46.142857142857146, max: 155)
#
# Run: 50, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 47.16, max: 155)
#
# Run: 51, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 47.80392156862745, max: 155)
#
# Run: 52, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 48.73076923076923, max: 155)
#
# Run: 53, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 49, max: 155)
#
# Run: 54, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 49.74074074074074, max: 155)
#
# Run: 55, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 49.836363636363636, max: 155)
#
# Run: 56, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 50.357142857142854, max: 155)
#
# Run: 57, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 50.98245614035088, max: 155)
#
# Run: 58, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 51.39655172413793, max: 155)
#
# Run: 59, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 51.847457627118644, max: 155)
#
# Run: 60, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 52.71666666666667, max: 155)
#
# Run: 61, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 53.24590163934426, max: 155)
#
# Run: 62, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 54.08064516129032, max: 155)
#
# Run: 63, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 54.57142857142857, max: 155)
#
# Run: 64, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 55.515625, max: 155)
#
# Run: 65, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 56.646153846153844, max: 155)
#
# Run: 66, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 57.36363636363637, max: 155)
#
# Run: 67, exploration: 0.01, score: 273
# Scores: (min: 8, avg: 60.582089552238806, max: 273)
#
# Run: 68, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 61.661764705882355, max: 273)
#
# Run: 69, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 62.594202898550726, max: 273)
#
# Run: 70, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 63.7, max: 273)
#
# Run: 71, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 64.78873239436619, max: 273)
#
# Run: 72, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 65.77777777777777, max: 273)
#
# Run: 73, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 67.21917808219177, max: 273)
#
# Run: 74, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 68.79729729729729, max: 273)
#
# Run: 75, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 70.09333333333333, max: 273)
#
# Run: 76, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 71.85526315789474, max: 273)
#
# Run: 77, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 73.01298701298701, max: 273)
#
# Run: 78, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 73.93589743589743, max: 273)
#
# Run: 79, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 75.27848101265823, max: 273)
#
# Run: 80, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 76.7625, max: 273)
#
# Run: 81, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 78.07407407407408, max: 273)
#
# Run: 82, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 79.1951219512195, max: 273)
#
# Run: 83, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 80.3132530120482, max: 273)
#
# Run: 84, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 81.13095238095238, max: 273)
#
# Run: 85, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 82.10588235294118, max: 273)
#
# Run: 86, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 83.59302325581395, max: 273)
#
# Run: 87, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 84.19540229885058, max: 273)
#
# Run: 88, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 85.10227272727273, max: 273)
#
# Run: 89, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 86.10112359550561, max: 273)
#
# Run: 90, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 86.76666666666667, max: 273)
# Run: 91, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 87.2967032967033, max: 273)
#
# Run: 92, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 88.17391304347827, max: 273)
#
# Run: 93, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 89.18279569892474, max: 273)
#
# Run: 94, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 89.96808510638297, max: 273)
#
# Run: 95, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 90.88421052631578, max: 273)
#
# Run: 96, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 91.70833333333333, max: 273)
#
# Run: 97, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 92.30927835051547, max: 273)
#
# Run: 98, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 92.98979591836735, max: 273)
#
# Run: 99, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 93.8080808080808, max: 273)
#
# Run: 100, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 94.43, max: 273)
#
# Run: 101, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 96.12, max: 273)
#
# Run: 102, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 97.4, max: 273)
#
# Run: 103, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 98.93, max: 273)
#
# Run: 104, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 100.21, max: 273)
#
# Run: 105, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 101.44, max: 273)
#
# Run: 106, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 102.52, max: 273)
#
# Run: 107, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 103.85, max: 273)
#
# Run: 108, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 105.21, max: 273)
#
# Run: 109, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 106.71, max: 273)
#
# Run: 110, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 108.15, max: 273)
#
# Run: 111, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 109.56, max: 273)
#
# Run: 112, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 110.92, max: 273)
#
# Run: 113, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 112.42, max: 273)
#
# Run: 114, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 113.74, max: 273)
#
# Run: 115, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 115.01, max: 273)
#
# Run: 116, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 116.18, max: 273)
#
# Run: 117, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 117.4, max: 273)
#
# Run: 118, exploration: 0.01, score: 169
# Scores: (min: 10, avg: 119.01, max: 273)
#
# Run: 119, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 120.34, max: 273)
#
# Run: 120, exploration: 0.01, score: 151
# Scores: (min: 17, avg: 121.75, max: 273)
#
# Run: 121, exploration: 0.01, score: 139
# Scores: (min: 17, avg: 122.76, max: 273)
#
# Run: 122, exploration: 0.01, score: 171
# Scores: (min: 19, avg: 124.3, max: 273)
#
# Run: 123, exploration: 0.01, score: 161
# Scores: (min: 19, avg: 125.71, max: 273)
#
# Run: 124, exploration: 0.01, score: 140
# Scores: (min: 27, avg: 126.92, max: 273)
#
# Run: 125, exploration: 0.01, score: 147
# Scores: (min: 39, avg: 128.12, max: 273)
#
# Run: 126, exploration: 0.01, score: 153
# Scores: (min: 39, avg: 129.18, max: 273)
#
# Run: 127, exploration: 0.01, score: 165
# Scores: (min: 39, avg: 129.52, max: 273)
#
# Run: 128, exploration: 0.01, score: 147
# Scores: (min: 39, avg: 129.7, max: 273)
#
# Run: 129, exploration: 0.01, score: 134
# Scores: (min: 39, avg: 130.47, max: 273)
#
# Run: 130, exploration: 0.01, score: 142
# Scores: (min: 39, avg: 131.5, max: 273)
#
# Run: 131, exploration: 0.01, score: 142
# Scores: (min: 39, avg: 132.21, max: 273)
#
# Run: 132, exploration: 0.01, score: 200
# Scores: (min: 39, avg: 133.51, max: 273)
#
# Run: 133, exploration: 0.01, score: 134
# Scores: (min: 49, avg: 134.46, max: 273)
#
# Run: 134, exploration: 0.01, score: 137
# Scores: (min: 49, avg: 134.92, max: 273)
#
# Run: 135, exploration: 0.01, score: 155
# Scores: (min: 49, avg: 134.97, max: 273)
#
# Run: 136, exploration: 0.01, score: 123
# Scores: (min: 52, avg: 135.71, max: 273)
#
# Run: 137, exploration: 0.01, score: 186
# Scores: (min: 52, avg: 136.71, max: 273)
#
# Run: 138, exploration: 0.01, score: 166
# Scores: (min: 52, avg: 137.21, max: 273)
#
# Run: 139, exploration: 0.01, score: 140
# Scores: (min: 52, avg: 137.76, max: 273)
#
# Run: 140, exploration: 0.01, score: 146
# Scores: (min: 52, avg: 137.67, max: 273)
#
# Run: 141, exploration: 0.01, score: 146
# Scores: (min: 52, avg: 138.37, max: 273)
#
# Run: 142, exploration: 0.01, score: 129
# Scores: (min: 52, avg: 139.1, max: 273)
#
# Run: 143, exploration: 0.01, score: 154
# Scores: (min: 52, avg: 140.09, max: 273)
#
# Run: 144, exploration: 0.01, score: 146
# Scores: (min: 52, avg: 140.84, max: 273)
#
# Run: 145, exploration: 0.01, score: 167
# Scores: (min: 52, avg: 141.95, max: 273)
#
# Run: 146, exploration: 0.01, score: 137
# Scores: (min: 52, avg: 142.48, max: 273)
#
# Run: 147, exploration: 0.01, score: 138
# Scores: (min: 55, avg: 143.34, max: 273)
#
# Run: 148, exploration: 0.01, score: 214
# Scores: (min: 55, avg: 144.9, max: 273)
#
# Run: 149, exploration: 0.01, score: 149
# Scores: (min: 55, avg: 145.61, max: 273)
#
# Run: 150, exploration: 0.01, score: 163
# Scores: (min: 55, avg: 146.27, max: 273)
#
# Run: 151, exploration: 0.01, score: 177
# Scores: (min: 55, avg: 147.24, max: 273)
#
# Run: 152, exploration: 0.01, score: 98
# Scores: (min: 55, avg: 147.26, max: 273)
#
# Run: 153, exploration: 0.01, score: 181
# Scores: (min: 55, avg: 148.44, max: 273)
#
# Run: 154, exploration: 0.01, score: 162
# Scores: (min: 55, avg: 149.17, max: 273)
#
# Run: 155, exploration: 0.01, score: 129
# Scores: (min: 75, avg: 149.91, max: 273)
#
# Run: 156, exploration: 0.01, score: 187
# Scores: (min: 75, avg: 150.99, max: 273)
#
# Run: 157, exploration: 0.01, score: 176
# Scores: (min: 75, avg: 151.89, max: 273)
#
# Run: 158, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 151.25, max: 273)
#
# Run: 159, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 151.99, max: 273)
#
# Run: 160, exploration: 0.01, score: 163
# Scores: (min: 11, avg: 152.58, max: 273)
#
# Run: 161, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 153.35, max: 273)
#
# Run: 162, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 153.81, max: 273)
#
# Run: 163, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 154.57, max: 273)
#
# Run: 164, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 154.93, max: 273)
#
# Run: 165, exploration: 0.01, score: 168
# Scores: (min: 11, avg: 155.32, max: 273)
#
# Run: 166, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 155.9, max: 273)
#
# Run: 167, exploration: 0.01, score: 168
# Scores: (min: 11, avg: 154.85, max: 214)
#
# Run: 168, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 155, max: 214)
#
# Run: 169, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 155.33, max: 214)
#
# Run: 170, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 155.29, max: 214)
#
# Run: 171, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 155.53, max: 214)
#
# Run: 172, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 155.65, max: 214)
#
# Run: 173, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 155.48, max: 214)
#
# Run: 174, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 154.97, max: 214)
#
# Run: 175, exploration: 0.01, score: 173
# Scores: (min: 11, avg: 155.04, max: 214)
#
# Run: 176, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 154.51, max: 214)
#
# Run: 177, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 154.27, max: 214)
#
# Run: 178, exploration: 0.01, score: 142
# Scores: (min: 11, avg: 154.24, max: 214)
#
# Run: 179, exploration: 0.01, score: 82
# Scores: (min: 11, avg: 153.26, max: 214)
#
# Run: 180, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 152.84, max: 214)
#
# Run: 181, exploration: 0.01, score: 188
# Scores: (min: 11, avg: 152.89, max: 214)
#
# Run: 182, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 152.49, max: 214)
#
# Run: 183, exploration: 0.01, score: 175
# Scores: (min: 11, avg: 152.52, max: 214)
#
# Run: 184, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 152.55, max: 214)
#
# Run: 185, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 152.46, max: 214)
#
# Run: 186, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 151.92, max: 214)
#
# Run: 187, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 151.83, max: 214)
#
# Run: 188, exploration: 0.01, score: 116
# Scores: (min: 11, avg: 151.35, max: 214)
#
# Run: 189, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 151.04, max: 214)
#
# Run: 190, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 150.95, max: 214)
# Run: 191, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 151.03, max: 214)
#
# Run: 192, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 150.55, max: 214)
#
# Run: 193, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 150.43, max: 214)
#
# Run: 194, exploration: 0.01, score: 166
# Scores: (min: 11, avg: 150.46, max: 214)
#
# Run: 195, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 150.14, max: 214)
#
# Run: 196, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 149.96, max: 214)
#
# Run: 197, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 150.07, max: 214)
#
# Run: 198, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 149.92, max: 214)
#
# Run: 199, exploration: 0.01, score: 188
# Scores: (min: 11, avg: 150.06, max: 214)
#
# Run: 200, exploration: 0.01, score: 157
# Scores: (min: 11, avg: 150.07, max: 214)
#
# Run: 201, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 149.59, max: 214)
#
# Run: 202, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 149.36, max: 214)
#
# Run: 203, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 149.45, max: 214)
#
# Run: 204, exploration: 0.01, score: 175
# Scores: (min: 11, avg: 149.76, max: 214)
#
# Run: 205, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 150.04, max: 214)
#
# Run: 206, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 150.29, max: 214)
#
# Run: 207, exploration: 0.01, score: 235
# Scores: (min: 11, avg: 151.19, max: 235)
#
# Run: 208, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 150.93, max: 235)
#
# Run: 209, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 150.82, max: 235)
#
# Run: 210, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 150.73, max: 235)
#
# Run: 211, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 150.73, max: 235)
#
# Run: 212, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 150.71, max: 235)
#
# Run: 213, exploration: 0.01, score: 171
# Scores: (min: 11, avg: 150.83, max: 235)
#
# Run: 214, exploration: 0.01, score: 187
# Scores: (min: 11, avg: 151.27, max: 235)
#
# Run: 215, exploration: 0.01, score: 142
# Scores: (min: 11, avg: 151.31, max: 235)
#
# Run: 216, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 151.61, max: 235)
#
# Run: 217, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 151.31, max: 235)
#
# Run: 218, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 151.27, max: 235)
#
# Run: 219, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 151.17, max: 235)
#
# Run: 220, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 150.89, max: 235)
#
# Run: 221, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 150.99, max: 235)
#
# Run: 222, exploration: 0.01, score: 254
# Scores: (min: 11, avg: 151.82, max: 254)
#
# Run: 223, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 151.69, max: 254)
#
# Run: 224, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 151.8, max: 254)
#
# Run: 225, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 151.79, max: 254)
#
# Run: 226, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 151.85, max: 254)
#
# Run: 227, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 151.73, max: 254)
#
# Run: 228, exploration: 0.01, score: 158
# Scores: (min: 11, avg: 151.84, max: 254)
#
# Run: 229, exploration: 0.01, score: 238
# Scores: (min: 11, avg: 152.88, max: 254)
#
# Run: 230, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 153.11, max: 254)
#
# Run: 231, exploration: 0.01, score: 169
# Scores: (min: 11, avg: 153.38, max: 254)
#
# Run: 232, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 152.93, max: 254)
#
# Run: 233, exploration: 0.01, score: 268
# Scores: (min: 11, avg: 154.27, max: 268)
#
# Run: 234, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 154.33, max: 268)
#
# Run: 235, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 153.98, max: 268)
#
# Run: 236, exploration: 0.01, score: 188
# Scores: (min: 11, avg: 154.63, max: 268)
#
# Run: 237, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 154.24, max: 268)
#
# Run: 238, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 154.02, max: 268)
#
# Run: 239, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 153.8, max: 268)
#
# Run: 240, exploration: 0.01, score: 116
# Scores: (min: 11, avg: 153.5, max: 268)
#
# Run: 241, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 153.15, max: 268)
#
# Run: 242, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 153.6, max: 268)
#
# Run: 243, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 153.98, max: 268)
#
# Run: 244, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 154.13, max: 268)
#
# Run: 245, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 154.2, max: 268)
#
# Run: 246, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 154.36, max: 268)
#
# Run: 247, exploration: 0.01, score: 157
# Scores: (min: 11, avg: 154.55, max: 268)
#
# Run: 248, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 153.84, max: 268)
#
# Run: 249, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 153.91, max: 268)
#
# Run: 250, exploration: 0.01, score: 223
# Scores: (min: 11, avg: 154.51, max: 268)
#
# Run: 251, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 154.28, max: 268)
#
# Run: 252, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 154.97, max: 268)
#
# Run: 253, exploration: 0.01, score: 138
# Scores: (min: 11, avg: 154.54, max: 268)
#
# Run: 254, exploration: 0.01, score: 169
# Scores: (min: 11, avg: 154.61, max: 268)
#
# Run: 255, exploration: 0.01, score: 138
# Scores: (min: 11, avg: 154.7, max: 268)
#
# Run: 256, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 154.15, max: 268)
#
# Run: 257, exploration: 0.01, score: 25
# Scores: (min: 11, avg: 152.64, max: 268)
#
# Run: 258, exploration: 0.01, score: 14
# Scores: (min: 14, avg: 152.67, max: 268)
#
# Run: 259, exploration: 0.01, score: 105
# Scores: (min: 14, avg: 152.2, max: 268)
#
# Run: 260, exploration: 0.01, score: 124
# Scores: (min: 14, avg: 151.81, max: 268)
#
# Run: 261, exploration: 0.01, score: 96
# Scores: (min: 14, avg: 151.15, max: 268)
#
# Run: 262, exploration: 0.01, score: 196
# Scores: (min: 14, avg: 151.6, max: 268)
#
# Run: 263, exploration: 0.01, score: 125
# Scores: (min: 14, avg: 151.24, max: 268)
#
# Run: 264, exploration: 0.01, score: 154
# Scores: (min: 14, avg: 151.27, max: 268)
#
# Run: 265, exploration: 0.01, score: 158
# Scores: (min: 14, avg: 151.17, max: 268)
#
# Run: 266, exploration: 0.01, score: 168
# Scores: (min: 14, avg: 151.23, max: 268)
#
# Run: 267, exploration: 0.01, score: 130
# Scores: (min: 14, avg: 150.85, max: 268)
#
# Run: 268, exploration: 0.01, score: 124
# Scores: (min: 14, avg: 150.6, max: 268)
#
# Run: 269, exploration: 0.01, score: 175
# Scores: (min: 14, avg: 150.76, max: 268)
#
# Run: 270, exploration: 0.01, score: 163
# Scores: (min: 14, avg: 151.03, max: 268)
#
# Run: 271, exploration: 0.01, score: 112
# Scores: (min: 14, avg: 150.5, max: 268)
#
# Run: 272, exploration: 0.01, score: 126
# Scores: (min: 14, avg: 150.28, max: 268)
#
# Run: 273, exploration: 0.01, score: 143
# Scores: (min: 14, avg: 150.17, max: 268)
#
# Run: 274, exploration: 0.01, score: 16
# Scores: (min: 14, avg: 149, max: 268)
#
# Run: 275, exploration: 0.01, score: 145
# Scores: (min: 14, avg: 148.72, max: 268)
#
# Run: 276, exploration: 0.01, score: 159
# Scores: (min: 14, avg: 148.8, max: 268)
#
# Run: 277, exploration: 0.01, score: 158
# Scores: (min: 14, avg: 149.01, max: 268)
#
# Run: 278, exploration: 0.01, score: 16
# Scores: (min: 14, avg: 147.75, max: 268)
#
# Run: 279, exploration: 0.01, score: 18
# Scores: (min: 14, avg: 147.11, max: 268)
#
# Run: 280, exploration: 0.01, score: 13
# Scores: (min: 13, avg: 145.72, max: 268)
#
# Run: 281, exploration: 0.01, score: 168
# Scores: (min: 13, avg: 145.52, max: 268)
#
# Run: 282, exploration: 0.01, score: 194
# Scores: (min: 13, avg: 146.16, max: 268)
#
# Run: 283, exploration: 0.01, score: 125
# Scores: (min: 13, avg: 145.66, max: 268)
#
# Run: 284, exploration: 0.01, score: 178
# Scores: (min: 13, avg: 145.92, max: 268)
#
# Run: 285, exploration: 0.01, score: 267
# Scores: (min: 13, avg: 147.04, max: 268)
#
# Run: 286, exploration: 0.01, score: 152
# Scores: (min: 13, avg: 147, max: 268)
#
# Run: 287, exploration: 0.01, score: 140
# Scores: (min: 13, avg: 147.13, max: 268)
#
# Run: 288, exploration: 0.01, score: 119
# Scores: (min: 13, avg: 147.16, max: 268)
#
# Run: 289, exploration: 0.01, score: 139
# Scores: (min: 13, avg: 147.12, max: 268)
#
# Run: 290, exploration: 0.01, score: 126
# Scores: (min: 13, avg: 147.01, max: 268)
#
# Run: 291, exploration: 0.01, score: 166
# Scores: (min: 13, avg: 147.24, max: 268)
# Run: 292, exploration: 0.01, score: 132
# Scores: (min: 13, avg: 147.36, max: 268)
#
# Run: 293, exploration: 0.01, score: 126
# Scores: (min: 13, avg: 146.92, max: 268)
#
# Run: 294, exploration: 0.01, score: 187
# Scores: (min: 13, avg: 147.13, max: 268)
#
# Run: 295, exploration: 0.01, score: 188
# Scores: (min: 13, avg: 147.56, max: 268)
#
# Run: 296, exploration: 0.01, score: 213
# Scores: (min: 13, avg: 148.17, max: 268)
#
# Run: 297, exploration: 0.01, score: 139
# Scores: (min: 13, avg: 147.95, max: 268)
#
# Run: 298, exploration: 0.01, score: 230
# Scores: (min: 13, avg: 148.81, max: 268)
#
# Run: 299, exploration: 0.01, score: 153
# Scores: (min: 13, avg: 148.46, max: 268)
#
# Run: 300, exploration: 0.01, score: 124
# Scores: (min: 13, avg: 148.13, max: 268)
#
# Run: 301, exploration: 0.01, score: 169
# Scores: (min: 13, avg: 148.49, max: 268)
#
# Run: 302, exploration: 0.01, score: 164
# Scores: (min: 13, avg: 148.9, max: 268)
#
# Run: 303, exploration: 0.01, score: 157
# Scores: (min: 13, avg: 148.71, max: 268)
#
# Run: 304, exploration: 0.01, score: 129
# Scores: (min: 13, avg: 148.25, max: 268)
#
# Run: 305, exploration: 0.01, score: 162
# Scores: (min: 13, avg: 148.11, max: 268)
#
# Run: 306, exploration: 0.01, score: 200
# Scores: (min: 13, avg: 148.66, max: 268)
#
# Run: 307, exploration: 0.01, score: 160
# Scores: (min: 13, avg: 147.91, max: 268)
#
# Run: 308, exploration: 0.01, score: 133
# Scores: (min: 13, avg: 148.06, max: 268)
#
# Run: 309, exploration: 0.01, score: 146
# Scores: (min: 13, avg: 148.03, max: 268)
#
# Run: 310, exploration: 0.01, score: 171
# Scores: (min: 13, avg: 148.31, max: 268)
#
# Run: 311, exploration: 0.01, score: 171
# Scores: (min: 13, avg: 148.47, max: 268)
#
# Run: 312, exploration: 0.01, score: 130
# Scores: (min: 13, avg: 148.34, max: 268)
#
# Run: 313, exploration: 0.01, score: 159
# Scores: (min: 13, avg: 148.22, max: 268)
#
# Run: 314, exploration: 0.01, score: 203
# Scores: (min: 13, avg: 148.38, max: 268)
#
# Run: 315, exploration: 0.01, score: 159
# Scores: (min: 13, avg: 148.55, max: 268)
#
# Run: 316, exploration: 0.01, score: 143
# Scores: (min: 13, avg: 148.42, max: 268)
#
# Run: 317, exploration: 0.01, score: 120
# Scores: (min: 13, avg: 148.6, max: 268)
#
# Run: 318, exploration: 0.01, score: 150
# Scores: (min: 13, avg: 148.45, max: 268)
#
# Run: 319, exploration: 0.01, score: 131
# Scores: (min: 13, avg: 148.4, max: 268)
#
# Run: 320, exploration: 0.01, score: 129
# Scores: (min: 13, avg: 148.46, max: 268)
#
# Run: 321, exploration: 0.01, score: 155
# Scores: (min: 13, avg: 148.52, max: 268)
#
# Run: 322, exploration: 0.01, score: 155
# Scores: (min: 13, avg: 147.53, max: 268)
#
# Run: 323, exploration: 0.01, score: 137
# Scores: (min: 13, avg: 147.42, max: 268)
#
# Run: 324, exploration: 0.01, score: 136
# Scores: (min: 13, avg: 147.27, max: 268)
#
# Run: 325, exploration: 0.01, score: 316
# Scores: (min: 13, avg: 148.97, max: 316)
#
# Run: 326, exploration: 0.01, score: 282
# Scores: (min: 13, avg: 150.2, max: 316)
#
# Run: 327, exploration: 0.01, score: 178
# Scores: (min: 13, avg: 150.45, max: 316)
#
# Run: 328, exploration: 0.01, score: 132
# Scores: (min: 13, avg: 150.19, max: 316)
#
# Run: 329, exploration: 0.01, score: 290
# Scores: (min: 13, avg: 150.71, max: 316)
#
# Run: 330, exploration: 0.01, score: 136
# Scores: (min: 13, avg: 150.42, max: 316)
#
# Run: 331, exploration: 0.01, score: 258
# Scores: (min: 13, avg: 151.31, max: 316)
#
# Run: 332, exploration: 0.01, score: 307
# Scores: (min: 13, avg: 152.83, max: 316)
#
# Run: 333, exploration: 0.01, score: 109
# Scores: (min: 13, avg: 151.24, max: 316)
#
# Run: 334, exploration: 0.01, score: 147
# Scores: (min: 13, avg: 151.28, max: 316)
#
# Run: 335, exploration: 0.01, score: 153
# Scores: (min: 13, avg: 151.61, max: 316)
#
# Run: 336, exploration: 0.01, score: 162
# Scores: (min: 13, avg: 151.35, max: 316)
#
# Run: 337, exploration: 0.01, score: 205
# Scores: (min: 13, avg: 151.93, max: 316)
#
# Run: 338, exploration: 0.01, score: 379
# Scores: (min: 13, avg: 154.28, max: 379)
#
# Run: 339, exploration: 0.01, score: 63
# Scores: (min: 13, avg: 153.73, max: 379)
#
# Run: 340, exploration: 0.01, score: 130
# Scores: (min: 13, avg: 153.87, max: 379)
#
# Run: 341, exploration: 0.01, score: 193
# Scores: (min: 13, avg: 154.69, max: 379)
#
# Run: 342, exploration: 0.01, score: 106
# Scores: (min: 13, avg: 154.01, max: 379)
#
# Run: 343, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 152.2, max: 379)
#
# Run: 344, exploration: 0.01, score: 226
# Scores: (min: 11, avg: 152.85, max: 379)
#
# Run: 345, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 152.75, max: 379)
#
# Run: 346, exploration: 0.01, score: 158
# Scores: (min: 11, avg: 152.8, max: 379)
#
# Run: 347, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 152.74, max: 379)
#
# Run: 348, exploration: 0.01, score: 150
# Scores: (min: 11, avg: 152.81, max: 379)
#
# Run: 349, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 152.87, max: 379)
#
# Run: 350, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 152.23, max: 379)
#
# Run: 351, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 152.14, max: 379)
#
# Run: 352, exploration: 0.01, score: 206
# Scores: (min: 11, avg: 152.53, max: 379)
#
# Run: 353, exploration: 0.01, score: 175
# Scores: (min: 11, avg: 152.9, max: 379)
#
# Run: 354, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 152.65, max: 379)
#
# Run: 355, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 152.63, max: 379)
#
# Run: 356, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 152.92, max: 379)
#
# Run: 357, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 154.27, max: 379)
#
# Run: 358, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 155.8, max: 379)
#
# Run: 359, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 156.45, max: 379)
#
# Run: 360, exploration: 0.01, score: 291
# Scores: (min: 11, avg: 158.12, max: 379)
#
# Run: 361, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 158.75, max: 379)
#
# Run: 362, exploration: 0.01, score: 74
# Scores: (min: 11, avg: 157.53, max: 379)
#
# Run: 363, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 157.87, max: 379)
#
# Run: 364, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 157.86, max: 379)
#
# Run: 365, exploration: 0.01, score: 166
# Scores: (min: 11, avg: 157.94, max: 379)
#
# Run: 366, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 157.75, max: 379)
#
# Run: 367, exploration: 0.01, score: 178
# Scores: (min: 11, avg: 158.23, max: 379)
#
# Run: 368, exploration: 0.01, score: 91
# Scores: (min: 11, avg: 157.9, max: 379)
#
# Run: 369, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 157.68, max: 379)
#
# Run: 370, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 157.25, max: 379)
#
# Run: 371, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 157.83, max: 379)
#
# Run: 372, exploration: 0.01, score: 183
# Scores: (min: 11, avg: 158.4, max: 379)
#
# Run: 373, exploration: 0.01, score: 196
# Scores: (min: 11, avg: 158.93, max: 379)
#
# Run: 374, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 160.1, max: 379)
#
# Run: 375, exploration: 0.01, score: 58
# Scores: (min: 11, avg: 159.23, max: 379)
#
# Run: 376, exploration: 0.01, score: 80
# Scores: (min: 11, avg: 158.44, max: 379)
#
# Run: 377, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 158.38, max: 379)
#
# Run: 378, exploration: 0.01, score: 333
# Scores: (min: 11, avg: 161.55, max: 379)
#
# Run: 379, exploration: 0.01, score: 172
# Scores: (min: 11, avg: 163.09, max: 379)
#
# Run: 380, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 167.96, max: 500)
#
# Run: 381, exploration: 0.01, score: 350
# Scores: (min: 11, avg: 169.78, max: 500)
#
# Run: 382, exploration: 0.01, score: 199
# Scores: (min: 11, avg: 169.83, max: 500)
#
# Run: 383, exploration: 0.01, score: 178
# Scores: (min: 11, avg: 170.36, max: 500)
#
# Run: 384, exploration: 0.01, score: 121
# Scores: (min: 11, avg: 169.79, max: 500)
#
# Run: 385, exploration: 0.01, score: 140
# Scores: (min: 11, avg: 168.52, max: 500)
#
# Run: 386, exploration: 0.01, score: 234
# Scores: (min: 11, avg: 169.34, max: 500)
#
# Run: 387, exploration: 0.01, score: 408
# Scores: (min: 11, avg: 172.02, max: 500)
#
# Run: 388, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 171.95, max: 500)
#
# Run: 389, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 172.15, max: 500)
#
# Run: 390, exploration: 0.01, score: 227
# Scores: (min: 11, avg: 173.16, max: 500)
#
# Run: 391, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 171.6, max: 500)
#
# Run: 392, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 170.37, max: 500)
# Run: 393, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 170.42, max: 500)
#
# Run: 394, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 169.68, max: 500)
#
# Run: 395, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 168.96, max: 500)
#
# Run: 396, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 168.71, max: 500)
#
# Run: 397, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 168.71, max: 500)
#
# Run: 398, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 168.12, max: 500)
#
# Run: 399, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 167.9, max: 500)
#
# Run: 400, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 168.07, max: 500)
#
# Run: 401, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 168.17, max: 500)
#
# Run: 402, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 168.54, max: 500)
#
# Run: 403, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 168.4, max: 500)
#
# Run: 404, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 168.54, max: 500)
#
# Run: 405, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 168.35, max: 500)
#
# Run: 406, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 167.98, max: 500)
#
# Run: 407, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 167.84, max: 500)
#
# Run: 408, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 168.33, max: 500)
#
# Run: 409, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 168.63, max: 500)
#
# Run: 410, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 168.85, max: 500)
#
# Run: 411, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 169.08, max: 500)
#
# Run: 412, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 169.25, max: 500)
#
# Run: 413, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 168.98, max: 500)
#
# Run: 414, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 168.4, max: 500)
#
# Run: 415, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 168.43, max: 500)
#
# Run: 416, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 168.32, max: 500)
#
# Run: 417, exploration: 0.01, score: 280
# Scores: (min: 9, avg: 169.92, max: 500)
#
# Run: 418, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 170.16, max: 500)
#
# Run: 419, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 170.24, max: 500)
#
# Run: 420, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 170.54, max: 500)
#
# Run: 421, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 170.69, max: 500)
#
# Run: 422, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 170.87, max: 500)
#
# Run: 423, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 170.62, max: 500)
#
# Run: 424, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 170.29, max: 500)
#
# Run: 425, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 168.17, max: 500)
#
# Run: 426, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 167.24, max: 500)
#
# Run: 427, exploration: 0.01, score: 321
# Scores: (min: 9, avg: 168.67, max: 500)
#
# Run: 428, exploration: 0.01, score: 331
# Scores: (min: 9, avg: 170.66, max: 500)
#
# Run: 429, exploration: 0.01, score: 305
# Scores: (min: 9, avg: 170.81, max: 500)
#
# Run: 430, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 171.01, max: 500)
#
# Run: 431, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 169.17, max: 500)
#
# Run: 432, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 166.25, max: 500)
#
# Run: 433, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 165.34, max: 500)
#
# Run: 434, exploration: 0.01, score: 282
# Scores: (min: 9, avg: 166.69, max: 500)
#
# Run: 435, exploration: 0.01, score: 313
# Scores: (min: 9, avg: 168.29, max: 500)
#
# Run: 436, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 168.04, max: 500)
#
# Run: 437, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 167.82, max: 500)
#
# Run: 438, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 165.1, max: 500)
#
# Run: 439, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 165.8, max: 500)
#
# Run: 440, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 166.11, max: 500)
#
# Run: 441, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 165.6, max: 500)
#
# Run: 442, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 166.1, max: 500)
#
# Run: 443, exploration: 0.01, score: 246
# Scores: (min: 9, avg: 168.45, max: 500)
#
# Run: 444, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 168.07, max: 500)
#
# Run: 445, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 167.89, max: 500)
#
# Run: 446, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 168.02, max: 500)
#
# Run: 447, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 168.67, max: 500)
#
# Run: 448, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 168.48, max: 500)
#
# Run: 449, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 168.16, max: 500)
#
# Run: 450, exploration: 0.01, score: 220
# Scores: (min: 9, avg: 168.77, max: 500)
#
# Run: 451, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 168.51, max: 500)
#
# Run: 452, exploration: 0.01, score: 351
# Scores: (min: 9, avg: 169.96, max: 500)
#
# Run: 453, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 169.15, max: 500)
#
# Run: 454, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 169.96, max: 500)
#
# Run: 455, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 170.61, max: 500)
#
# Run: 456, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 170.33, max: 500)
#
# Run: 457, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 170.64, max: 500)
#
# Run: 458, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 171.4, max: 500)
#
# Run: 459, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 170.99, max: 500)
#
# Run: 460, exploration: 0.01, score: 312
# Scores: (min: 9, avg: 171.2, max: 500)
#
# Run: 461, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 171.44, max: 500)
#
# Run: 462, exploration: 0.01, score: 389
# Scores: (min: 9, avg: 174.59, max: 500)
#
# Run: 463, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 174.24, max: 500)
#
# Run: 464, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 174.58, max: 500)
#
# Run: 465, exploration: 0.01, score: 276
# Scores: (min: 9, avg: 175.68, max: 500)
#
# Run: 466, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 179.19, max: 500)
#
# Run: 467, exploration: 0.01, score: 343
# Scores: (min: 9, avg: 180.84, max: 500)
#
# Run: 468, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 181.69, max: 500)
#
# Run: 469, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 181.48, max: 500)
#
# Run: 470, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 182.26, max: 500)
#
# Run: 471, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 182.02, max: 500)
#
# Run: 472, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 181.7, max: 500)
#
# Run: 473, exploration: 0.01, score: 307
# Scores: (min: 9, avg: 182.81, max: 500)
#
# Run: 474, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 183.42, max: 500)
#
# Run: 475, exploration: 0.01, score: 416
# Scores: (min: 9, avg: 187, max: 500)
#
# Run: 476, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 187.23, max: 500)
#
# Run: 477, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 186.71, max: 500)
#
# Run: 478, exploration: 0.01, score: 242
# Scores: (min: 9, avg: 185.8, max: 500)
#
# Run: 479, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 186.85, max: 500)
#
# Run: 480, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 183.2, max: 500)
#
# Run: 481, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 181.19, max: 500)
#
# Run: 482, exploration: 0.01, score: 269
# Scores: (min: 9, avg: 181.89, max: 500)
#
# Run: 483, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 182.37, max: 500)
#
# Run: 484, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 183.5, max: 500)
#
# Run: 485, exploration: 0.01, score: 283
# Scores: (min: 9, avg: 184.93, max: 500)
#
# Run: 486, exploration: 0.01, score: 290
# Scores: (min: 9, avg: 185.49, max: 500)
#
# Run: 487, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 182.89, max: 500)
#
# Run: 488, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 184.11, max: 500)
#
# Run: 489, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 183.7, max: 500)
#
# Run: 490, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 182.63, max: 500)
#
# Run: 491, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 184.12, max: 500)
#
# Run: 492, exploration: 0.01, score: 399
# Scores: (min: 15, avg: 188.02, max: 500)
#
# Run: 493, exploration: 0.01, score: 152
# Scores: (min: 15, avg: 188.23, max: 500)
#
# Run: 494, exploration: 0.01, score: 122
# Scores: (min: 15, avg: 188.32, max: 500)
# Run: 495, exploration: 0.01, score: 77
# Scores: (min: 15, avg: 187.93, max: 500)
#
# Run: 496, exploration: 0.01, score: 255
# Scores: (min: 15, avg: 188.6, max: 500)
#
# Run: 497, exploration: 0.01, score: 20
# Scores: (min: 15, avg: 187.41, max: 500)
#
# Run: 498, exploration: 0.01, score: 101
# Scores: (min: 15, avg: 186.71, max: 500)
#
# Run: 499, exploration: 0.01, score: 121
# Scores: (min: 15, avg: 186.61, max: 500)
#
# Run: 500, exploration: 0.01, score: 161
# Scores: (min: 15, avg: 186.81, max: 500)
#
# Run: 501, exploration: 0.01, score: 326
# Scores: (min: 15, avg: 188.28, max: 500)
#
# Run: 502, exploration: 0.01, score: 176
# Scores: (min: 15, avg: 188.03, max: 500)
#
# Run: 503, exploration: 0.01, score: 389
# Scores: (min: 15, avg: 190.49, max: 500)
#
# Run: 504, exploration: 0.01, score: 500
# Scores: (min: 15, avg: 194.06, max: 500)
#
# Run: 505, exploration: 0.01, score: 468
# Scores: (min: 15, avg: 197.31, max: 500)
#
# Solved in 405 runs, 505 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-29db8405d828> in cartpole()
#     123             if terminal:
#     124                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# --> 125                 score_logger.add_score(step, run)
#     126                 break
#     127             dqn_solver.experience_replay()
#
# U:\Module Five\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
  
from scores.score_logger import ScoreLogger

my_bool = bool(True)  # Define a NumPy boolean variable
  
ENV_NAME = "CartPole-v1"

#* # Experiment 3: Higher Learning Rate

import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
# #* Version 1: Main code for default parameters.

# GAMMA = 0.95  
# LEARNING_RATE = 0.001  
  
# MEMORY_SIZE = 1000000  
# BATCH_SIZE = 20  
  
# EXPLORATION_MAX = 1.0  
# EXPLORATION_MIN = 0.01  
# EXPLORATION_DECAY = 0.995

# # * Version 2: Increased Exploration Decay

# GAMMA = 0.95
# LEARNING_RATE = 0.001
# EXPLORATION_MAX = 1.0
# EXPLORATION_MIN = 0.01
# EXPLORATION_DECAY = 0.99  # Slower decay, longer exploration phase
# MEMORY_SIZE = 1000000
# BATCH_SIZE = 20

#* Version 3: Increased Learning Rate
#
GAMMA = 0.95
LEARNING_RATE = 0.005  # Faster learning
EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995
MEMORY_SIZE = 1000000
BATCH_SIZE = 20 

# #* Version 4: Reduced Discount Factor
# #
# # Experiment 4: Reduced Discount Factor
# # GAMMA = 0.8  # Less emphasis on future rewards
# # LEARNING_RATE = 0.001
# # EXPLORATION_MAX = 1.0
# # EXPLORATION_MIN = 0.01
# # EXPLORATION_DECAY = 0.995
# # MEMORY_SIZE = 1000000
# # BATCH_SIZE = 20
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 12
# Scores: (min: 12, avg: 12, max: 12)
#
# Run: 2, exploration: 0.9322301194154049, score: 22
# Scores: (min: 12, avg: 17, max: 22)
#
# Run: 3, exploration: 0.8734200960253871, score: 14
# Scores: (min: 12, avg: 16, max: 22)
#
# Run: 4, exploration: 0.7666961448653229, score: 27
# Scores: (min: 12, avg: 18.75, max: 27)
#
# Run: 5, exploration: 0.7255664080186093, score: 12
# Scores: (min: 12, avg: 17.4, max: 27)
#
# Run: 6, exploration: 0.6935613678313175, score: 10
# Scores: (min: 10, avg: 16.166666666666668, max: 27)
#
# Run: 7, exploration: 0.6149486215357263, score: 25
# Scores: (min: 10, avg: 17.428571428571427, max: 27)
#
# Run: 8, exploration: 0.5819594443402982, score: 12
# Scores: (min: 10, avg: 16.75, max: 27)
#
# Run: 9, exploration: 0.5535075230322891, score: 11
# Scores: (min: 10, avg: 16.11111111111111, max: 27)
#
# Run: 10, exploration: 0.5238143793828016, score: 12
# Scores: (min: 10, avg: 15.7, max: 27)
#
# Run: 11, exploration: 0.4932355662165453, score: 13
# Scores: (min: 10, avg: 15.454545454545455, max: 27)
#
# Run: 12, exploration: 0.45522245551230495, score: 17
# Scores: (min: 10, avg: 15.583333333333334, max: 27)
#
# Run: 13, exploration: 0.42650460709830135, score: 14
# Scores: (min: 10, avg: 15.461538461538462, max: 27)
#
# Run: 14, exploration: 0.40769130904675194, score: 10
# Scores: (min: 10, avg: 15.071428571428571, max: 27)
#
# Run: 15, exploration: 0.3877593341372176, score: 11
# Scores: (min: 10, avg: 14.8, max: 27)
#
# Run: 16, exploration: 0.3614809303671764, score: 15
# Scores: (min: 10, avg: 14.8125, max: 27)
#
# Run: 17, exploration: 0.3472722151889232, score: 9
# Scores: (min: 9, avg: 14.470588235294118, max: 27)
#
# Run: 18, exploration: 0.3302941218954743, score: 11
# Scores: (min: 9, avg: 14.277777777777779, max: 27)
#
# Run: 19, exploration: 0.31101247816653554, score: 13
# Scores: (min: 9, avg: 14.210526315789474, max: 27)
#
# Run: 20, exploration: 0.2913921604631864, score: 14
# Scores: (min: 9, avg: 14.2, max: 27)
#
# Run: 21, exploration: 0.27714603575484437, score: 11
# Scores: (min: 9, avg: 14.047619047619047, max: 27)
#
# Run: 22, exploration: 0.25966219297210513, score: 14
# Scores: (min: 9, avg: 14.045454545454545, max: 27)
#
# Run: 23, exploration: 0.24696734223472733, score: 11
# Scores: (min: 9, avg: 13.91304347826087, max: 27)
#
# Run: 24, exploration: 0.23489314109365644, score: 11
# Scores: (min: 9, avg: 13.791666666666666, max: 27)
#
# Run: 25, exploration: 0.22453190559909803, score: 10
# Scores: (min: 9, avg: 13.64, max: 27)
#
# Run: 26, exploration: 0.21570623976979014, score: 9
# Scores: (min: 9, avg: 13.461538461538462, max: 27)
#
# Run: 27, exploration: 0.20619134658263935, score: 10
# Scores: (min: 9, avg: 13.333333333333334, max: 27)
#
# Run: 28, exploration: 0.19808659230739353, score: 9
# Scores: (min: 9, avg: 13.178571428571429, max: 27)
#
# Run: 29, exploration: 0.1903004112552766, score: 9
# Scores: (min: 9, avg: 13.03448275862069, max: 27)
#
# Run: 30, exploration: 0.18190617987607657, score: 10
# Scores: (min: 9, avg: 12.933333333333334, max: 27)
#
# Run: 31, exploration: 0.17388222158237718, score: 10
# Scores: (min: 9, avg: 12.838709677419354, max: 27)
#
# Run: 32, exploration: 0.1662122034722543, score: 10
# Scores: (min: 9, avg: 12.75, max: 27)
#
# Run: 33, exploration: 0.15888051309497406, score: 10
# Scores: (min: 9, avg: 12.666666666666666, max: 27)
#
# Run: 34, exploration: 0.1518722266715875, score: 10
# Scores: (min: 9, avg: 12.588235294117647, max: 27)
#
# Run: 35, exploration: 0.14229132060898236, score: 14
# Scores: (min: 9, avg: 12.628571428571428, max: 27)
#
# Run: 36, exploration: 0.13601479046086049, score: 10
# Scores: (min: 9, avg: 12.555555555555555, max: 27)
#
# Run: 37, exploration: 0.13001512070402377, score: 10
# Scores: (min: 9, avg: 12.486486486486486, max: 27)
#
# Run: 38, exploration: 0.12365869841532712, score: 11
# Scores: (min: 9, avg: 12.447368421052632, max: 27)
#
# Run: 39, exploration: 0.11702497557911415, score: 12
# Scores: (min: 9, avg: 12.435897435897436, max: 27)
#
# Run: 40, exploration: 0.11130363979080501, score: 11
# Scores: (min: 9, avg: 12.4, max: 27)
#
# Run: 41, exploration: 0.10692863247165257, score: 9
# Scores: (min: 9, avg: 12.317073170731707, max: 27)
#
# Run: 42, exploration: 0.10221196540767843, score: 10
# Scores: (min: 9, avg: 12.261904761904763, max: 27)
#
# Run: 43, exploration: 0.09819432413732986, score: 9
# Scores: (min: 9, avg: 12.186046511627907, max: 27)
#
# Run: 44, exploration: 0.0943346041173244, score: 9
# Scores: (min: 9, avg: 12.113636363636363, max: 27)
#
# Run: 45, exploration: 0.0906265979439563, score: 9
# Scores: (min: 9, avg: 12.044444444444444, max: 27)
#
# Run: 46, exploration: 0.08662902049662846, score: 10
# Scores: (min: 9, avg: 12, max: 27)
#
# Run: 47, exploration: 0.08280777787605056, score: 10
# Scores: (min: 9, avg: 11.957446808510639, max: 27)
#
# Run: 48, exploration: 0.07836551983717477, score: 12
# Scores: (min: 9, avg: 11.958333333333334, max: 27)
#
# Run: 49, exploration: 0.07566352740075044, score: 8
# Scores: (min: 8, avg: 11.877551020408163, max: 27)
#
# Run: 50, exploration: 0.07268942442628039, score: 9
# Scores: (min: 8, avg: 11.82, max: 27)
#
# Run: 51, exploration: 0.07018314008827135, score: 8
# Scores: (min: 8, avg: 11.745098039215685, max: 27)
#
# Run: 52, exploration: 0.06708733218678724, score: 10
# Scores: (min: 8, avg: 11.711538461538462, max: 27)
#
# Run: 53, exploration: 0.06412808167716157, score: 10
# Scores: (min: 8, avg: 11.679245283018869, max: 27)
#
# Run: 54, exploration: 0.06129936495526111, score: 10
# Scores: (min: 8, avg: 11.648148148148149, max: 27)
#
# Run: 55, exploration: 0.058889873488111255, score: 9
# Scores: (min: 8, avg: 11.6, max: 27)
#
# Run: 56, exploration: 0.056575091797066025, score: 9
# Scores: (min: 8, avg: 11.553571428571429, max: 27)
#
# Run: 57, exploration: 0.0543512971290831, score: 9
# Scores: (min: 8, avg: 11.508771929824562, max: 27)
#
# Run: 58, exploration: 0.052214913061211746, score: 9
# Scores: (min: 8, avg: 11.46551724137931, max: 27)
#
# Run: 59, exploration: 0.049911691230058335, score: 10
# Scores: (min: 8, avg: 11.440677966101696, max: 27)
#
# Run: 60, exploration: 0.04794981455780219, score: 9
# Scores: (min: 8, avg: 11.4, max: 27)
#
# Run: 61, exploration: 0.046296535966244, score: 8
# Scores: (min: 8, avg: 11.344262295081966, max: 27)
#
# Run: 62, exploration: 0.04425437624418858, score: 10
# Scores: (min: 8, avg: 11.32258064516129, max: 27)
#
# Run: 63, exploration: 0.04230229704853423, score: 10
# Scores: (min: 8, avg: 11.301587301587302, max: 27)
#
# Run: 64, exploration: 0.04043632488927963, score: 10
# Scores: (min: 8, avg: 11.28125, max: 27)
#
# Run: 65, exploration: 0.03884689602888724, score: 9
# Scores: (min: 8, avg: 11.246153846153845, max: 27)
#
# Run: 66, exploration: 0.037319942779450235, score: 9
# Scores: (min: 8, avg: 11.212121212121213, max: 27)
#
# Run: 67, exploration: 0.03549537564593805, score: 11
# Scores: (min: 8, avg: 11.208955223880597, max: 27)
#
# Run: 68, exploration: 0.03359121130473201, score: 12
# Scores: (min: 8, avg: 11.220588235294118, max: 27)
#
# Run: 69, exploration: 0.032433008066058915, score: 8
# Scores: (min: 8, avg: 11.173913043478262, max: 27)
#
# Run: 70, exploration: 0.030083851847510768, score: 16
# Scores: (min: 8, avg: 11.242857142857142, max: 27)
#
# Run: 71, exploration: 0.02861305625559891, score: 11
# Scores: (min: 8, avg: 11.23943661971831, max: 27)
#
# Run: 72, exploration: 0.027626496583102015, score: 8
# Scores: (min: 8, avg: 11.194444444444445, max: 27)
#
# Run: 73, exploration: 0.02654058308574668, score: 9
# Scores: (min: 8, avg: 11.164383561643836, max: 27)
#
# Run: 74, exploration: 0.02536986677519817, score: 10
# Scores: (min: 8, avg: 11.14864864864865, max: 27)
#
# Run: 75, exploration: 0.024129537298457977, score: 11
# Scores: (min: 8, avg: 11.146666666666667, max: 27)
#
# Run: 76, exploration: 0.023065173234186005, score: 10
# Scores: (min: 8, avg: 11.131578947368421, max: 27)
#
# Run: 77, exploration: 0.022158551474944856, score: 9
# Scores: (min: 8, avg: 11.103896103896103, max: 27)
#
# Run: 78, exploration: 0.020044857891939702, score: 21
# Scores: (min: 8, avg: 11.23076923076923, max: 27)
#
# Run: 79, exploration: 0.019256955536244666, score: 9
# Scores: (min: 8, avg: 11.20253164556962, max: 27)
#
# Run: 80, exploration: 0.018407523107991184, score: 10
# Scores: (min: 8, avg: 11.1875, max: 27)
#
# Run: 81, exploration: 0.016239489508417658, score: 26
# Scores: (min: 8, avg: 11.37037037037037, max: 27)
# Run: 82, exploration: 0.013626370684745774, score: 36
# Scores: (min: 8, avg: 11.670731707317072, max: 36)
#
# Run: 83, exploration: 0.013090759526015528, score: 9
# Scores: (min: 8, avg: 11.63855421686747, max: 36)
#
# Run: 84, exploration: 0.01208186940302195, score: 17
# Scores: (min: 8, avg: 11.702380952380953, max: 36)
#
# Run: 85, exploration: 0.011039504743095268, score: 19
# Scores: (min: 8, avg: 11.788235294117648, max: 36)
#
# Run: 86, exploration: 0.010239902030817916, score: 16
# Scores: (min: 8, avg: 11.837209302325581, max: 36)
#
# Run: 87, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.839080459770114, max: 36)
#
# Run: 88, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.806818181818182, max: 36)
#
# Run: 89, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.932584269662922, max: 36)
#
# Run: 90, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.966666666666667, max: 36)
#
# Run: 91, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.043956043956044, max: 36)
#
# Run: 92, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.130434782608695, max: 36)
#
# Run: 93, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.236559139784946, max: 36)
#
# Run: 94, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.340425531914894, max: 36)
#
# Run: 95, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.31578947368421, max: 36)
#
# Run: 96, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.40625, max: 36)
#
# Run: 97, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.402061855670103, max: 36)
#
# Run: 98, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.408163265306122, max: 36)
#
# Run: 99, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.434343434343434, max: 36)
#
# Run: 100, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 12.81, max: 50)
#
# Run: 101, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.8, max: 50)
#
# Run: 102, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 12.85, max: 50)
#
# Run: 103, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.86, max: 50)
#
# Run: 104, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 13.03, max: 50)
#
# Run: 105, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.08, max: 50)
#
# Run: 106, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 13.3, max: 50)
#
# Run: 107, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 13.57, max: 52)
#
# Run: 108, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 13.92, max: 52)
#
# Run: 109, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14.08, max: 52)
#
# Run: 110, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.24, max: 52)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.21, max: 52)
#
# Run: 112, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 14.39, max: 52)
#
# Run: 113, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.41, max: 52)
#
# Run: 114, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.49, max: 52)
#
# Run: 115, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.63, max: 52)
#
# Run: 116, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 14.82, max: 52)
#
# Run: 117, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.98, max: 52)
#
# Run: 118, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 15.09, max: 52)
#
# Run: 119, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.07, max: 52)
#
# Run: 120, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.03, max: 52)
#
# Run: 121, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 15.31, max: 52)
#
# Run: 122, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.26, max: 52)
#
# Run: 123, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 15.52, max: 52)
#
# Run: 124, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.61, max: 52)
#
# Run: 125, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 16.03, max: 52)
#
# Run: 126, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 16.58, max: 64)
#
# Run: 127, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 17.13, max: 65)
#
# Run: 128, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.17, max: 65)
#
# Run: 129, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 17.49, max: 65)
#
# Run: 130, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 17.83, max: 65)
#
# Run: 131, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 17.97, max: 65)
#
# Run: 132, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.99, max: 65)
#
# Run: 133, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.19, max: 65)
#
# Run: 134, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 18.85, max: 76)
#
# Run: 135, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.84, max: 76)
#
# Run: 136, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 18.95, max: 76)
#
# Run: 137, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 19.38, max: 76)
#
# Run: 138, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 19.53, max: 76)
#
# Run: 139, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 19.66, max: 76)
#
# Run: 140, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.7, max: 76)
#
# Run: 141, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.74, max: 76)
#
# Run: 142, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 19.96, max: 76)
#
# Run: 143, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.01, max: 76)
#
# Run: 144, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 20.64, max: 76)
#
# Run: 145, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.75, max: 76)
#
# Run: 146, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.79, max: 76)
#
# Run: 147, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 21.18, max: 76)
#
# Run: 148, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 21.44, max: 76)
#
# Run: 149, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.49, max: 76)
#
# Run: 150, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 21.59, max: 76)
#
# Run: 151, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21.74, max: 76)
#
# Run: 152, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 21.83, max: 76)
#
# Run: 153, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 22.08, max: 76)
#
# Run: 154, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 22.71, max: 76)
#
# Run: 155, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 22.76, max: 76)
#
# Run: 156, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 22.9, max: 76)
#
# Run: 157, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 23.03, max: 76)
#
# Run: 158, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 23.16, max: 76)
#
# Run: 159, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 23.25, max: 76)
#
# Run: 160, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 23.64, max: 76)
#
# Run: 161, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 23.81, max: 76)
#
# Run: 162, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.88, max: 76)
#
# Run: 163, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 24.13, max: 76)
#
# Run: 164, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 24.3, max: 76)
#
# Run: 165, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 24.39, max: 76)
#
# Run: 166, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 24.55, max: 76)
#
# Run: 167, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 24.55, max: 76)
#
# Run: 168, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 24.88, max: 76)
#
# Run: 169, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 25.03, max: 76)
#
# Run: 170, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 25.34, max: 76)
#
# Run: 171, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 25.48, max: 76)
#
# Run: 172, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 25.69, max: 76)
#
# Run: 173, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 25.88, max: 76)
#
# Run: 174, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 26.39, max: 76)
#
# Run: 175, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 26.54, max: 76)
#
# Run: 176, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 26.68, max: 76)
#
# Run: 177, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 26.76, max: 76)
#
# Run: 178, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 26.9, max: 76)
#
# Run: 179, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 26.95, max: 76)
#
# Run: 180, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 27.53, max: 76)
#
# Run: 181, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 27.48, max: 76)
#
# Run: 182, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 27.38, max: 76)
#
# Run: 183, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 27.5, max: 76)
# Run: 184, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 27.56, max: 76)
#
# Run: 185, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 27.51, max: 76)
#
# Run: 186, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 27.72, max: 76)
#
# Run: 187, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 27.8, max: 76)
#
# Run: 188, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 27.96, max: 76)
#
# Run: 189, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 27.94, max: 76)
#
# Run: 190, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 28.12, max: 76)
#
# Run: 191, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 28.09, max: 76)
#
# Run: 192, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 28.03, max: 76)
#
# Run: 193, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 27.92, max: 76)
#
# Run: 194, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 27.95, max: 76)
#
# Run: 195, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 28.14, max: 76)
#
# Run: 196, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 28.15, max: 76)
#
# Run: 197, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 28.23, max: 76)
#
# Run: 198, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 28.4, max: 76)
#
# Run: 199, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 28.56, max: 76)
#
# Run: 200, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 28.53, max: 76)
#
# Run: 201, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 28.62, max: 76)
#
# Run: 202, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 28.66, max: 76)
#
# Run: 203, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 28.63, max: 76)
#
# Run: 204, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 28.43, max: 76)
#
# Run: 205, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 28.68, max: 76)
#
# Run: 206, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 28.73, max: 76)
#
# Run: 207, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 28.34, max: 76)
#
# Run: 208, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 28.03, max: 76)
#
# Run: 209, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 27.88, max: 76)
#
# Run: 210, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 27.98, max: 76)
#
# Run: 211, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 28.08, max: 76)
#
# Run: 212, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 27.98, max: 76)
#
# Run: 213, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 28.26, max: 76)
#
# Run: 214, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 28.41, max: 76)
#
# Run: 215, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 28.37, max: 76)
#
# Run: 216, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 28.5, max: 76)
#
# Run: 217, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 28.45, max: 76)
#
# Run: 218, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 28.5, max: 76)
#
# Run: 219, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 28.73, max: 76)
#
# Run: 220, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 28.74, max: 76)
#
# Run: 221, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 28.61, max: 76)
#
# Run: 222, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 28.65, max: 76)
#
# Run: 223, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 28.42, max: 76)
#
# Run: 224, exploration: 0.01, score: 48
# Scores: (min: 11, avg: 28.7, max: 76)
#
# Run: 225, exploration: 0.01, score: 21
# Scores: (min: 11, avg: 28.39, max: 76)
#
# Run: 226, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 27.91, max: 76)
#
# Run: 227, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 27.36, max: 76)
#
# Run: 228, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 27.37, max: 76)
#
# Run: 229, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 27.23, max: 76)
#
# Run: 230, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 26.92, max: 76)
#
# Run: 231, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 26.82, max: 76)
#
# Run: 232, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 26.84, max: 76)
#
# Run: 233, exploration: 0.01, score: 54
# Scores: (min: 10, avg: 27.08, max: 76)
#
# Run: 234, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 26.47, max: 73)
#
# Run: 235, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 27, max: 73)
#
# Run: 236, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 27.27, max: 73)
#
# Run: 237, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 27.01, max: 73)
#
# Run: 238, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 26.84, max: 73)
#
# Run: 239, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 26.69, max: 73)
#
# Run: 240, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 26.64, max: 73)
#
# Run: 241, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 26.65, max: 73)
#
# Run: 242, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 26.53, max: 73)
#
# Run: 243, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 26.49, max: 73)
#
# Run: 244, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 25.92, max: 73)
#
# Run: 245, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 25.85, max: 73)
#
# Run: 246, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 25.87, max: 73)
#
# Run: 247, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 25.55, max: 73)
#
# Run: 248, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 25.34, max: 73)
#
# Run: 249, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 25.48, max: 73)
#
# Run: 250, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 25.66, max: 73)
#
# Run: 251, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 25.66, max: 73)
#
# Run: 252, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 26.09, max: 73)
#
# Run: 253, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 26.02, max: 73)
#
# Run: 254, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 25.47, max: 68)
#
# Run: 255, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 25.48, max: 68)
#
# Run: 256, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 25.47, max: 68)
#
# Run: 257, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 25.37, max: 68)
#
# Run: 258, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 25.39, max: 68)
#
# Run: 259, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 25.62, max: 68)
#
# Run: 260, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 25.45, max: 68)
#
# Run: 261, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 25.57, max: 68)
#
# Run: 262, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 25.58, max: 68)
#
# Run: 263, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 25.87, max: 68)
#
# Run: 264, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 25.74, max: 68)
#
# Run: 265, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 26.39, max: 83)
#
# Run: 266, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 26.33, max: 83)
#
# Run: 267, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 26.49, max: 83)
#
# Run: 268, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 26.48, max: 83)
#
# Run: 269, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 26.63, max: 83)
#
# Run: 270, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 26.43, max: 83)
#
# Run: 271, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 26.42, max: 83)
#
# Run: 272, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 26.48, max: 83)
#
# Run: 273, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 26.46, max: 83)
#
# Run: 274, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 26.33, max: 83)
#
# Run: 275, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 26.57, max: 83)
#
# Run: 276, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 26.54, max: 83)
#
# Run: 277, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 26.8, max: 83)
#
# Run: 278, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 26.66, max: 83)
#
# Run: 279, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 26.81, max: 83)
#
# Run: 280, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 26.63, max: 83)
#
# Run: 281, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 26.71, max: 83)
#
# Run: 282, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 26.81, max: 83)
#
# Run: 283, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 26.81, max: 83)
#
# Run: 284, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 26.73, max: 83)
#
# Run: 285, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 27.31, max: 83)
#
# Run: 286, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 27.12, max: 83)
#
# Run: 287, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 27.16, max: 83)
#
# Run: 288, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 27.24, max: 83)
# Run: 289, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 27.47, max: 83)
#
# Run: 290, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 27.52, max: 83)
#
# Run: 291, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 27.95, max: 83)
#
# Run: 292, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 28.52, max: 83)
#
# Run: 293, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 28.65, max: 83)
#
# Run: 294, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 29.94, max: 154)
#
# Run: 295, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 30.16, max: 154)
#
# Run: 296, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 30.13, max: 154)
#
# Run: 297, exploration: 0.01, score: 54
# Scores: (min: 9, avg: 30.47, max: 154)
#
# Run: 298, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 30.81, max: 154)
#
# Run: 299, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.58, max: 154)
#
# Run: 300, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.22, max: 154)
#
# Run: 301, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 30.47, max: 154)
#
# Run: 302, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 30.28, max: 154)
#
# Run: 303, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 30.44, max: 154)
#
# Run: 304, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 30.32, max: 154)
#
# Run: 305, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 30.74, max: 154)
#
# Run: 306, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 30.53, max: 154)
#
# Run: 307, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 30.68, max: 154)
#
# Run: 308, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 30.77, max: 154)
#
# Run: 309, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 31, max: 154)
#
# Run: 310, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 31.02, max: 154)
#
# Run: 311, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 31.39, max: 154)
#
# Run: 312, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 31.27, max: 154)
#
# Run: 313, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 31.04, max: 154)
#
# Run: 314, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 31.19, max: 154)
#
# Run: 315, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 31.16, max: 154)
#
# Run: 316, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 31.4, max: 154)
#
# Run: 317, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 31.59, max: 154)
#
# Run: 318, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.43, max: 154)
#
# Run: 319, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 32.2, max: 154)
#
# Run: 320, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 32.5, max: 154)
#
# Run: 321, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 32.63, max: 154)
#
# Run: 322, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 32.9, max: 154)
#
# Run: 323, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.85, max: 154)
#
# Run: 324, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.47, max: 154)
#
# Run: 325, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.35, max: 154)
#
# Run: 326, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.28, max: 154)
#
# Run: 327, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.27, max: 154)
#
# Run: 328, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.22, max: 154)
#
# Run: 329, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.05, max: 154)
#
# Run: 330, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.02, max: 154)
#
# Run: 331, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.98, max: 154)
#
# Run: 332, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.94, max: 154)
#
# Run: 333, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.5, max: 154)
#
# Run: 334, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.45, max: 154)
#
# Run: 335, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.88, max: 154)
#
# Run: 336, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.5, max: 154)
#
# Run: 337, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.33, max: 154)
#
# Run: 338, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.33, max: 154)
#
# Run: 339, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.32, max: 154)
#
# Run: 340, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 31.11, max: 154)
#
# Run: 341, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 32.78, max: 181)
#
# Run: 342, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 33.27, max: 181)
#
# Run: 343, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 33.41, max: 181)
#
# Run: 344, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 34.63, max: 181)
#
# Run: 345, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 34.98, max: 181)
#
# Run: 346, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 34.96, max: 181)
#
# Run: 347, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 35.39, max: 181)
#
# Run: 348, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 35.74, max: 181)
#
# Run: 349, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 35.91, max: 181)
#
# Run: 350, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 36.21, max: 181)
#
# Run: 351, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 36.31, max: 181)
#
# Run: 352, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.78, max: 181)
#
# Run: 353, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.59, max: 181)
#
# Run: 354, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.5, max: 181)
#
# Run: 355, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 35.55, max: 181)
#
# Run: 356, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 36.06, max: 181)
#
# Run: 357, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 36.4, max: 181)
#
# Run: 358, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 36.86, max: 181)
#
# Run: 359, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 37.42, max: 181)
#
# Run: 360, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 37.23, max: 181)
#
# Run: 361, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 37, max: 181)
#
# Run: 362, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 37.09, max: 181)
#
# Run: 363, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 37.09, max: 181)
#
# Run: 364, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 37.46, max: 181)
#
# Run: 365, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 37.05, max: 181)
#
# Run: 366, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 37.92, max: 181)
#
# Run: 367, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 38.15, max: 181)
#
# Run: 368, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 39.66, max: 195)
#
# Run: 369, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 39.65, max: 195)
#
# Run: 370, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 40.9, max: 195)
#
# Run: 371, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 41.93, max: 195)
#
# Run: 372, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 41.78, max: 195)
#
# Run: 373, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 42.11, max: 195)
#
# Run: 374, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 42.89, max: 195)
#
# Run: 375, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 44.06, max: 195)
#
# Run: 376, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 44.39, max: 195)
#
# Run: 377, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 44.62, max: 195)
#
# Run: 378, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 45.14, max: 195)
#
# Run: 379, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 45.52, max: 195)
#
# Run: 380, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 46.21, max: 195)
#
# Run: 381, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 47.74, max: 195)
#
# Run: 382, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 47.68, max: 195)
#
# Run: 383, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 47.94, max: 195)
#
# Run: 384, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 49.41, max: 195)
#
# Run: 385, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 49.81, max: 195)
#
# Run: 386, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 50, max: 195)
#
# Run: 387, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 51.05, max: 195)
#
# Run: 388, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 51.64, max: 195)
#
# Run: 389, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.3, max: 195)
#
# Run: 390, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 52.64, max: 195)
#
# Run: 391, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 53.03, max: 195)
#
# Run: 392, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 54.24, max: 195)
# Run: 393, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 54.11, max: 195)
#
# Run: 394, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 54.56, max: 199)
#
# Run: 395, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 55.46, max: 199)
#
# Run: 396, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 55.38, max: 199)
#
# Run: 397, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 54.94, max: 199)
#
# Run: 398, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 54.51, max: 199)
#
# Run: 399, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 54.65, max: 199)
#
# Run: 400, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 54.77, max: 199)
#
# Run: 401, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 55.44, max: 199)
#
# Run: 402, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 55.48, max: 199)
#
# Run: 403, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 55.9, max: 199)
#
# Run: 404, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 55.91, max: 199)
#
# Run: 405, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 55.22, max: 199)
#
# Run: 406, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 56.26, max: 199)
#
# Run: 407, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 57.43, max: 199)
#
# Run: 408, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 58.31, max: 199)
#
# Run: 409, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 60.01, max: 205)
#
# Run: 410, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 61.38, max: 205)
#
# Run: 411, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 61.65, max: 205)
#
# Run: 412, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 62.56, max: 205)
#
# Run: 413, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 63.46, max: 205)
#
# Run: 414, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 64.12, max: 205)
#
# Run: 415, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 64.24, max: 205)
#
# Run: 416, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 63.66, max: 205)
#
# Run: 417, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 64.9, max: 205)
#
# Run: 418, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 65.36, max: 205)
#
# Run: 419, exploration: 0.01, score: 211
# Scores: (min: 9, avg: 66.36, max: 211)
#
# Run: 420, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 68.21, max: 226)
#
# Run: 421, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 68.37, max: 226)
#
# Run: 422, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 68.57, max: 226)
#
# Run: 423, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 68.75, max: 226)
#
# Run: 424, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 69.01, max: 226)
#
# Run: 425, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 70.05, max: 226)
#
# Run: 426, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 70.15, max: 226)
#
# Run: 427, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 71.54, max: 226)
#
# Run: 428, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 71.78, max: 226)
#
# Run: 429, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 72.6, max: 226)
#
# Run: 430, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 73.18, max: 226)
#
# Run: 431, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 74.7, max: 226)
#
# Run: 432, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 76.72, max: 226)
#
# Run: 433, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 77.3, max: 226)
#
# Run: 434, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 77.89, max: 226)
#
# Run: 435, exploration: 0.01, score: 434
# Scores: (min: 9, avg: 82.14, max: 434)
#
# Run: 436, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 82.65, max: 434)
#
# Run: 437, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 84.38, max: 434)
#
# Run: 438, exploration: 0.01, score: 215
# Scores: (min: 9, avg: 86.44, max: 434)
#
# Run: 439, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 87.88, max: 434)
#
# Run: 440, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 87.92, max: 434)
#
# Run: 441, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 86.44, max: 434)
#
# Run: 442, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 87.41, max: 434)
#
# Run: 443, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 88.8, max: 434)
#
# Run: 444, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 88.83, max: 434)
#
# Run: 445, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 89.47, max: 434)
#
# Run: 446, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 90.36, max: 434)
#
# Run: 447, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 90.75, max: 434)
#
# Run: 448, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 91.37, max: 434)
#
# Run: 449, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 92.26, max: 434)
#
# Run: 450, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 92.83, max: 434)
#
# Run: 451, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 93.81, max: 434)
#
# Run: 452, exploration: 0.01, score: 96
# Scores: (min: 9, avg: 94.68, max: 434)
#
# Run: 453, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 95.95, max: 434)
#
# Run: 454, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 96.67, max: 434)
#
# Run: 455, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 97.67, max: 434)
#
# Run: 456, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 98.49, max: 434)
#
# Run: 457, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 99.52, max: 434)
#
# Run: 458, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 100.24, max: 434)
#
# Run: 459, exploration: 0.01, score: 158
# Scores: (min: 10, avg: 100.84, max: 434)
#
# Run: 460, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 102.24, max: 434)
#
# Run: 461, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 103.47, max: 434)
#
# Run: 462, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 104.69, max: 434)
#
# Run: 463, exploration: 0.01, score: 287
# Scores: (min: 10, avg: 106.92, max: 434)
#
# Run: 464, exploration: 0.01, score: 169
# Scores: (min: 10, avg: 108.1, max: 434)
#
# Run: 465, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 109.48, max: 434)
#
# Run: 466, exploration: 0.01, score: 218
# Scores: (min: 10, avg: 110.6, max: 434)
#
# Run: 467, exploration: 0.01, score: 224
# Scores: (min: 10, avg: 112.34, max: 434)
#
# Run: 468, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 112.1, max: 434)
#
# Run: 469, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 112.71, max: 434)
#
# Run: 470, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 113.01, max: 434)
#
# Run: 471, exploration: 0.01, score: 320
# Scores: (min: 10, avg: 114.94, max: 434)
#
# Run: 472, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 116.24, max: 434)
#
# Run: 473, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 116.96, max: 434)
#
# Run: 474, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 117.81, max: 434)
#
# Run: 475, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 117.36, max: 434)
#
# Run: 476, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 116.91, max: 434)
#
# Run: 477, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 116.51, max: 434)
#
# Run: 478, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 116.06, max: 434)
#
# Run: 479, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 115.55, max: 434)
#
# Run: 480, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 115.31, max: 434)
#
# Run: 481, exploration: 0.01, score: 456
# Scores: (min: 9, avg: 118.05, max: 456)
#
# Run: 482, exploration: 0.01, score: 340
# Scores: (min: 9, avg: 121.15, max: 456)
#
# Run: 483, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 122.73, max: 456)
#
# Run: 484, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 121.81, max: 456)
#
# Run: 485, exploration: 0.01, score: 90
# Scores: (min: 9, avg: 121.59, max: 456)
#
# Run: 486, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 122.06, max: 456)
#
# Run: 487, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 122.86, max: 456)
#
# Run: 488, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 124.07, max: 456)
#
# Run: 489, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 125.1, max: 456)
#
# Run: 490, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 124.64, max: 456)
#
# Run: 491, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 124.85, max: 456)
#
# Run: 492, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 124.42, max: 456)
#
# Run: 493, exploration: 0.01, score: 334
# Scores: (min: 9, avg: 127.65, max: 456)
#
# Run: 494, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 126.71, max: 456)
#
# Run: 495, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 126.68, max: 456)
# Run: 496, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 128.81, max: 456)
#
# Run: 497, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 129.17, max: 456)
#
# Run: 498, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 130.08, max: 456)
#
# Run: 499, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 131.17, max: 456)
#
# Run: 500, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 131.67, max: 456)
#
# Run: 501, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 131.61, max: 456)
#
# Run: 502, exploration: 0.01, score: 75
# Scores: (min: 9, avg: 132.2, max: 456)
#
# Run: 503, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 132.21, max: 456)
#
# Run: 504, exploration: 0.01, score: 76
# Scores: (min: 9, avg: 132.84, max: 456)
#
# Run: 505, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 133.42, max: 456)
#
# Run: 506, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 133.4, max: 456)
#
# Run: 507, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 133.1, max: 456)
#
# Run: 508, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 132.59, max: 456)
#
# Run: 509, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 131.12, max: 456)
#
# Run: 510, exploration: 0.01, score: 56
# Scores: (min: 9, avg: 129.91, max: 456)
#
# Run: 511, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 130.6, max: 456)
#
# Run: 512, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 130.49, max: 456)
#
# Run: 513, exploration: 0.01, score: 87
# Scores: (min: 9, avg: 130.25, max: 456)
#
# Run: 514, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 129.81, max: 456)
#
# Run: 515, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 130.2, max: 456)
#
# Run: 516, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 130.55, max: 456)
#
# Run: 517, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 129.84, max: 456)
#
# Run: 518, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 129.8, max: 456)
#
# Run: 519, exploration: 0.01, score: 440
# Scores: (min: 9, avg: 132.09, max: 456)
#
# Run: 520, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 129.92, max: 456)
#
# Run: 521, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 129.97, max: 456)
#
# Run: 522, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 130.75, max: 456)
#
# Run: 523, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 131.54, max: 456)
#
# Run: 524, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 132.31, max: 456)
#
# Run: 525, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 131.42, max: 456)
#
# Run: 526, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 132.35, max: 456)
#
# Run: 527, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 132.41, max: 456)
#
# Run: 528, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 132.89, max: 456)
#
# Run: 529, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 132.88, max: 456)
#
# Run: 530, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 133.2, max: 456)
#
# Run: 531, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 132.69, max: 456)
#
# Run: 532, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 131.56, max: 456)
#
# Run: 533, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 132.04, max: 456)
#
# Run: 534, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 132.38, max: 456)
#
# Run: 535, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 128.99, max: 456)
#
# Run: 536, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 129.43, max: 456)
#
# Run: 537, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 128.63, max: 456)
#
# Run: 538, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 127.99, max: 456)
#
# Run: 539, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 127.1, max: 456)
#
# Run: 540, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 127.7, max: 456)
#
# Run: 541, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 128.7, max: 456)
#
# Run: 542, exploration: 0.01, score: 82
# Scores: (min: 9, avg: 127.86, max: 456)
#
# Run: 543, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 127.42, max: 456)
#
# Run: 544, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 126.83, max: 456)
#
# Run: 545, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 126.34, max: 456)
#
# Run: 546, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 126.05, max: 456)
#
# Run: 547, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 126.09, max: 456)
#
# Run: 548, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 125.64, max: 456)
#
# Run: 549, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 124.95, max: 456)
#
# Run: 550, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 124.43, max: 456)
#
# Run: 551, exploration: 0.01, score: 80
# Scores: (min: 9, avg: 123.92, max: 456)
#
# Run: 552, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 123.9, max: 456)
#
# Run: 553, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 123.38, max: 456)
#
# Run: 554, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 123.93, max: 456)
#
# Run: 555, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 123.9, max: 456)
#
# Run: 556, exploration: 0.01, score: 261
# Scores: (min: 9, avg: 124.96, max: 456)
#
# Run: 557, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 124.8, max: 456)
#
# Run: 558, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 124.42, max: 456)
#
# Run: 559, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 124.38, max: 456)
#
# Run: 560, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 123.93, max: 456)
#
# Run: 561, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 123.47, max: 456)
#
# Run: 562, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 122.69, max: 456)
#
# Run: 563, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 120.94, max: 456)
#
# Run: 564, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 120.39, max: 456)
#
# Run: 565, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 119.7, max: 456)
#
# Run: 566, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 118.56, max: 456)
#
# Run: 567, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 116.72, max: 456)
#
# Run: 568, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 116.06, max: 456)
#
# Run: 569, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 116.09, max: 456)
#
# Run: 570, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 115.25, max: 456)
#
# Run: 571, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 113.41, max: 456)
#
# Run: 572, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 113.12, max: 456)
#
# Run: 573, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 112.87, max: 456)
#
# Run: 574, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 112.84, max: 456)
#
# Run: 575, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 112.45, max: 456)
#
# Run: 576, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 112.57, max: 456)
#
# Run: 577, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 112.49, max: 456)
#
# Run: 578, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 112.43, max: 456)
#
# Run: 579, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 113.28, max: 456)
#
# Run: 580, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 113.43, max: 456)
#
# Run: 581, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 109.8, max: 440)
#
# ...
# Scores: (min: 8, avg: 14.96, max: 106)
#
# Run: 3347, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.3, max: 106)
#
# Run: 3348, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.36, max: 106)
#
# Run: 3349, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.44, max: 86)
#
# Run: 3350, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.68, max: 58)
#
# Run: 3351, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.63, max: 58)
#
# Run: 3352, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.25, max: 58)
#
# Run: 3353, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.21, max: 58)
#
# Run: 3354, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.91, max: 58)
#
# Run: 3355, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.42, max: 32)
#
# Run: 3356, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.28, max: 32)
#
# Run: 3357, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.05, max: 32)
#
# Run: 3358, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10, max: 32)
#
# Run: 3359, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.9, max: 32)
#
# Run: 3360, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 9.89, max: 32)
#
# Run: 3361, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.66, max: 19)
#
# Run: 3362, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 9.69, max: 19)
#
# Run: 3363, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.69, max: 19)
#
# Run: 3364, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.7, max: 19)
#
# Run: 3365, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 9.75, max: 19)
#
# Run: 3366, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.77, max: 19)
#
# Run: 3367, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 9.82, max: 19)
#
# Run: 3368, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.82, max: 19)
#
# Run: 3369, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.83, max: 19)
#
# Run: 3370, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 9.87, max: 19)
#
# Run: 3371, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.88, max: 19)
#
# Run: 3372, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 9.93, max: 19)
#
# Run: 3373, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.93, max: 19)
#
# Run: 3374, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.01, max: 19)
#
# Run: 3375, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.04, max: 19)
#
# Run: 3376, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.03, max: 19)
#
# Run: 3377, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.07, max: 19)
#
# Run: 3378, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.08, max: 19)
#
# Run: 3379, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.08, max: 19)
#
# Run: 3380, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.1, max: 19)
#
# Run: 3381, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.14, max: 19)
#
# Run: 3382, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.14, max: 19)
#
# Run: 3383, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.14, max: 19)
#
# Run: 3384, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 10.33, max: 28)
#
# Run: 3385, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 10.44, max: 28)
#
# Run: 3386, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.44, max: 28)
#
# Run: 3387, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.43, max: 28)
#
# Run: 3388, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.43, max: 28)
#
# Run: 3389, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.42, max: 28)
#
# Run: 3390, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.42, max: 28)
#
# Run: 3391, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.39, max: 28)
#
# Run: 3392, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.41, max: 28)
#
# Run: 3393, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.41, max: 28)
#
# Run: 3394, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.41, max: 28)
#
# Run: 3395, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.42, max: 28)
#
# Run: 3396, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.43, max: 28)
#
# Run: 3397, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.46, max: 28)
#
# Run: 3398, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.47, max: 28)
#
# Run: 3399, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.57, max: 28)
#
# Run: 3400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.58, max: 28)
#
# Run: 3401, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 10.66, max: 28)
#
# Run: 3402, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.66, max: 28)
#
# Run: 3403, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.74, max: 28)
#
# Run: 3404, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.73, max: 28)
#
# Run: 3405, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 10.84, max: 28)
#
# Run: 3406, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 11.01, max: 28)
#
# Run: 3407, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.05, max: 28)
# Run: 3408, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.2, max: 28)
#
# Run: 3409, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.2, max: 28)
#
# Run: 3410, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.2, max: 28)
#
# Run: 3411, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.2, max: 28)
#
# Run: 3412, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.21, max: 28)
#
# Run: 3413, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.2, max: 28)
#
# Run: 3414, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.22, max: 28)
#
# Run: 3415, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.26, max: 28)
#
# Run: 3416, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.37, max: 28)
#
# Run: 3417, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.43, max: 28)
#
# Run: 3418, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.42, max: 28)
#
# Run: 3419, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.42, max: 28)
#
# Run: 3420, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.46, max: 28)
#
# Run: 3421, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.51, max: 28)
#
# Run: 3422, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.66, max: 28)
#
# Run: 3423, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.67, max: 28)
#
# Run: 3424, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.66, max: 28)
#
# Run: 3425, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 11.96, max: 39)
#
# Run: 3426, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.98, max: 39)
#
# Run: 3427, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.98, max: 39)
#
# Run: 3428, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 12.15, max: 39)
#
# Run: 3429, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.23, max: 39)
#
# Run: 3430, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.19, max: 39)
#
# Run: 3431, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.2, max: 39)
#
# Run: 3432, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.21, max: 39)
#
# Run: 3433, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.31, max: 39)
#
# Run: 3434, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.31, max: 39)
#
# Run: 3435, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.32, max: 39)
#
# Run: 3436, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 12.59, max: 39)
#
# Run: 3437, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.73, max: 39)
#
# Run: 3438, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.72, max: 39)
#
# Run: 3439, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.84, max: 39)
#
# Run: 3440, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.82, max: 39)
#
# Run: 3441, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.84, max: 39)
#
# Run: 3442, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.85, max: 39)
#
# Run: 3443, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.86, max: 39)
#
# Run: 3444, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.88, max: 39)
#
# Run: 3445, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 13.12, max: 39)
#
# Run: 3446, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.1, max: 39)
#
# Run: 3447, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.09, max: 39)
#
# Run: 3448, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.1, max: 39)
#
# Run: 3449, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.05, max: 39)
#
# Run: 3450, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.03, max: 39)
#
# Run: 3451, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.95, max: 39)
#
# Run: 3452, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.95, max: 39)
#
# Run: 3453, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.95, max: 39)
#
# Run: 3454, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.98, max: 39)
#
# Run: 3455, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.98, max: 39)
#
# Run: 3456, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13, max: 39)
#
# Run: 3457, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.02, max: 39)
#
# Run: 3458, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.99, max: 39)
#
# Run: 3459, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13, max: 39)
#
# Run: 3460, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.93, max: 39)
#
# Run: 3461, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.96, max: 39)
#
# Run: 3462, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.95, max: 39)
#
# Run: 3463, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 13.46, max: 60)
#
# Run: 3464, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.46, max: 60)
#
# Run: 3465, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.43, max: 60)
#
# Run: 3466, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.43, max: 60)
#
# Run: 3467, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 13.62, max: 60)
#
# Run: 3468, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.62, max: 60)
#
# Run: 3469, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 13.68, max: 60)
#
# Run: 3470, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.68, max: 60)
#
# Run: 3471, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.67, max: 60)
#
# Run: 3472, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 13.74, max: 60)
#
# Run: 3473, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.76, max: 60)
#
# Run: 3474, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.71, max: 60)
#
# Run: 3475, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.69, max: 60)
#
# Run: 3476, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.7, max: 60)
#
# Run: 3477, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 14.13, max: 60)
#
# Run: 3478, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.16, max: 60)
#
# Run: 3479, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 14.8, max: 73)
#
# Run: 3480, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 16.29, max: 159)
#
# Run: 3481, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 16.58, max: 159)
#
# Run: 3482, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.58, max: 159)
#
# Run: 3483, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.58, max: 159)
#
# Run: 3484, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.38, max: 159)
#
# Run: 3485, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.27, max: 159)
#
# Run: 3486, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.27, max: 159)
#
# Run: 3487, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.3, max: 159)
#
# Run: 3488, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.3, max: 159)
#
# Run: 3489, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.3, max: 159)
#
# Run: 3490, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.3, max: 159)
#
# Run: 3491, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.3, max: 159)
#
# Run: 3492, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.31, max: 159)
#
# Run: 3493, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.3, max: 159)
#
# Run: 3494, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.3, max: 159)
#
# Run: 3495, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.29, max: 159)
#
# Run: 3496, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.29, max: 159)
#
# Run: 3497, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.27, max: 159)
#
# Run: 3498, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.26, max: 159)
#
# Run: 3499, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 16.83, max: 159)
#
# Run: 3500, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 17.99, max: 159)
#
# Run: 3501, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 18.71, max: 159)
#
# Run: 3502, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.75, max: 159)
#
# Run: 3503, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 19.57, max: 159)
#
# Run: 3504, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19.66, max: 159)
#
# Run: 3505, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 20.62, max: 159)
#
# Run: 3506, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.5, max: 159)
#
# Run: 3507, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 20.53, max: 159)
#
# Run: 3508, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 21.69, max: 159)
#
# Run: 3509, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 21.81, max: 159)
#
# Run: 3510, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 21.88, max: 159)
#
# Run: 3511, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 21.99, max: 159)
# Run: 3512, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 22.08, max: 159)
#
# Run: 3513, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 22.12, max: 159)
#
# Run: 3514, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 22.19, max: 159)
#
# Run: 3515, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 22.4, max: 159)
#
# Run: 3516, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 22.34, max: 159)
#
# Run: 3517, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 22.53, max: 159)
#
# Run: 3518, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 22.58, max: 159)
#
# Run: 3519, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 22.64, max: 159)
#
# Run: 3520, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 22.87, max: 159)
#
# Run: 3521, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 22.9, max: 159)
#
# Run: 3522, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 22.82, max: 159)
#
# Run: 3523, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 22.86, max: 159)
#
# Run: 3524, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 23.12, max: 159)
#
# Run: 3525, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 22.93, max: 159)
#
# Run: 3526, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 23.14, max: 159)
#
# Run: 3527, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 24.1, max: 159)
#
# Run: 3528, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 24.06, max: 159)
#
# Run: 3529, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 24.08, max: 159)
#
# Run: 3530, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 24.92, max: 159)
#
# Run: 3531, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 24.98, max: 159)
#
# Run: 3532, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 24.99, max: 159)
#
# Run: 3533, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 24.95, max: 159)
#
# Run: 3534, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 25.37, max: 159)
#
# Run: 3535, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 25.41, max: 159)
#
# Run: 3536, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 25.52, max: 159)
#
# Run: 3537, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 25.63, max: 159)
#
# Run: 3538, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 25.8, max: 159)
#
# Run: 3539, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 26.54, max: 159)
#
# Run: 3540, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 27.21, max: 159)
#
# Run: 3541, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 27.27, max: 159)
#
# Run: 3542, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.25, max: 159)
#
# Run: 3543, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.24, max: 159)
#
# Run: 3544, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 27.84, max: 159)
#
# Run: 3545, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 28.31, max: 159)
#
# Run: 3546, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 29.14, max: 159)
#
# Run: 3547, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 29.88, max: 159)
#
# Run: 3548, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 30.7, max: 159)

# %% [markdown]
# <hr><br>
#
# # Overview
#
# The "cartpole" problem, which is also called the "inverted pendulum" problem, is a classic test in reinforcement learning. The goal is to balance a pole on a moving cart by controlling the cart's movement. This assignment uses OpenAI Gym, a toolkit for developing and testing reinforcement learning algorithms, and provides a Python environment to explore Q-learning techniques for solving the problem.
#
# ## Reinforcement Learning Concepts and Application
#
# **Goal of the Agent:**
# The agent aims to keep the pole balanced for as long as possible. Each timestep with the pole upright adds to the agent's score. Success is defined by achieving an average score above a set threshold over consecutive runs.
#
# **State Values:**
# The environment's state is described by four variables:
# > - Cart position
# > - Cart velocity
# > - Pole angle relative to vertical
# > - Angular velocity of the pole
#
# **Possible Actions:**
# The agent can:
# > - Push the cart to the left
# > - Push the cart to the right
#
# *Each action influences the environment's next state, shaping the agent's strategy.*
#
# **Reinforcement Algorithm Used:**
# The solution uses a Deep Q-Network (DQN), an advanced form of Q-learning that leverages a neural network to estimate the Q-value function.
#
# *Techniques like experience replay improve both learning efficiency and model stability.*
#
# <hr>
#
# ## Experience Replay Analysis
#
# **How Experience Replay Works:**
# Experience replay saves the agent's interactions in a replay buffer, allowing random mini-batches to be used for training.
#
# *This breaks the correlation between consecutive samples, improving both learning stability and efficiency.*
#
# **Effect of Discount Factor:**
# The discount factor ($\gamma$, GAMMA) determines the balance between immediate and future rewards. Higher values favor long-term planning, while lower values prioritize short-term outcomes.
#
# *Adjusting this factor shapes the agent's strategy and overall performance.*
# <hr>
#
# ## Neural Networks in Deep Q-Learning
#
# **Neural Network Architecture:**
# The DQN architecture includes:
# > - An input layer for the state variables.
# > - Hidden layers with ReLU activations for non-linear transformations.
# > - An output layer predicting Q-values for each action.
#
# **Efficiency Improvements:**
# The neural network helps the agent generalize decision-making across similar states, making it more efficient at managing high-dimensional environments and complex scenarios.
#
# **Impact of Learning Rate Adjustments:**
# The learning rate (LEARNING_RATE) dictates how quickly the network updates its weights during training. Higher rates speed up convergence but can cause instability, while lower rates provide more stable learning at the cost of slower progress.
# <hr>
# ***This experiment highlights the effectiveness of reinforcement learning in real-time control and balancing tasks. <br>Adjusting parameters like the discount factor and learning rate offers important insights for improving performance in more complex environments.***
#
# <!-- Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error. -->
